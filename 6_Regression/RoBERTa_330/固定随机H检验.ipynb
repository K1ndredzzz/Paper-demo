# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests
from linearmodels import PanelOLS, RandomEffects
from linearmodels.panel import compare
from scipy import stats
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv('stock_daily_sentiment.csv')
df['date'] = pd.to_datetime(df['date'])
df['stock_code'] = df['stock_code'].astype(str).str.zfill(6)

df = df.set_index(['stock_code', 'date'])

# 定义因变量和自变量
y = df['forward_ret_1d']  # 可以改为forward_ret_3d或forward_ret_5d
X = df[['avg_sentiment', 'sentiment_std', 
             'avg_intensity', 'comment_count',
             'close', 'volume', 'amount', 'amplitude',
             'pct_change', 'price_change', 'turnover_rate']]
X = sm.add_constant(X)

# 1. 固定效应模型
fixed_effects = PanelOLS(y, X, entity_effects=True, time_effects=True)
fe_results = fixed_effects.fit(cov_type='clustered', cluster_entity=True)
print("固定效应模型结果:")
print(fe_results)

# 2. 随机效应模型
random_effects = RandomEffects(y, X)
re_results = random_effects.fit(cov_type='clustered', cluster_entity=True)
print("\n随机效应模型结果:")
print(re_results)

comparison = compare({'FE': fe_results, 'RE': re_results}, stars = True)
print(comparison)

# 3. Hausman检验
def hausman_test(fe_model, re_model):
    # 提取系数和协方差矩阵
    b_fe = fe_model.params
    b_re = re_model.params
    
    # 去除常数项后的系数差
    b_diff = b_fe - b_re
    
    # 计算协方差矩阵差
    var_fe = fe_model.cov
    var_re = re_model.cov
    var_diff = var_fe - var_re
    
    # Hausman统计量
    H = np.dot(np.dot(b_diff.T, np.linalg.inv(var_diff)), b_diff)
    
    # 自由度(参数个数)
    df = len(b_fe)
    
    # p值
    p_value = 1 - stats.chi2.cdf(H, df)
    
    return H, p_value

H_stat, p_val = hausman_test(fe_results, re_results)
print("\nHausman检验结果:")
print(f"统计量: {H_stat:.4f}")
print(f"P值: {p_val:.4f}")
print("结论:", "拒绝随机效应，使用固定效应" if p_val < 0.05 else "接受随机效应")

# 输出回归结果到Excel（可选）
def export_results(results, filename):
    # 获取置信区间DataFrame
    conf_int = results.conf_int()
    
    # 创建摘要DataFrame
    summary_df = pd.DataFrame({
        'coefficient': results.params,
        'std_error': results.std_errors,
        't_stat': results.tstats,
        'p_value': results.pvalues,
        'conf_int_lower': conf_int.iloc[:, 0],  # 使用iloc正确获取第一列
        'conf_int_upper': conf_int.iloc[:, 1]   # 使用iloc正确获取第二列
    })
    summary_df.to_excel(filename)
# 可以添加行业固定效应
# 如果需要控制行业效应，在数据中加入行业虚拟变量
# 添加行业虚拟变量，但删除一个类别避免完全共线性
# 按市值大小分组回归
for group in df.groupby('industry'):
    industry_data = group[1]
    y = industry_data['forward_ret_1d']
    X = industry_data[['avg_sentiment', 'sentiment_std', 
             'avg_intensity', 'comment_count',
             'close', 'volume', 'amount', 'amplitude',
             'pct_change', 'price_change', 'turnover_rate']]
    X = sm.add_constant(X)
    
    fixed_effects = PanelOLS(y, X, entity_effects=True, time_effects=True)
    fe_results = fixed_effects.fit(cov_type='clustered', cluster_entity=True)
    print(f"\n{group[0]}行业的回归结果:")
    print(fe_results)
    export_results(fe_results, f'{group[0]}fixed_effects_results.xlsx')



export_results(re_results, 'random_effects_results.xlsx')
# Out:
# 固定效应模型结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.0594
# Estimator:                   PanelOLS   R-squared (Between):             -480.88
# No. Observations:                1989   R-squared (Within):               0.0738
# Date:                Sun, Mar 16 2025   R-squared (Overall):             -23.929
# Time:                        00:47:47   Log-likelihood                    4821.6
# Cov. Estimator:             Clustered
#                                         F-statistic:                      10.627
# Entities:                         111   P-value                           0.0000
# Avg Obs:                       17.919   Distribution:                 F(11,1850)
# Min Obs:                       12.000
# Max Obs:                       18.000   F-statistic (robust):             4.7320
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                 F(11,1850)
# Avg Obs:                       110.50
# Min Obs:                       108.00
# Max Obs:                       111.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.0453     0.0250     1.8145     0.0698     -0.0037      0.0943
# avg_sentiment     0.0101     0.0045     2.2496     0.0246      0.0013      0.0190
# sentiment_std     0.0079     0.0118     0.6725     0.5013     -0.0152      0.0311
# avg_intensity     0.0091     0.0202     0.4496     0.6530     -0.0305      0.0487
# comment_count -7.357e-06  7.805e-06    -0.9427     0.3460  -2.266e-05    7.95e-06
# close            -0.0008     0.0003    -3.2394     0.0012     -0.0013     -0.0003
# volume        -2.762e-09  2.249e-09    -1.2280     0.2196  -7.173e-09   1.649e-09
# amount        -1.832e-12  1.382e-12    -1.3258     0.1851  -4.543e-12   8.783e-13
# amplitude        -0.0012     0.0007    -1.8914     0.0587     -0.0025   4.587e-05
# pct_change        0.0001     0.0003     0.3219     0.7476     -0.0005      0.0007
# price_change      0.0003     0.0002     1.6512     0.0989  -5.788e-05      0.0007
# turnover_rate     0.0008     0.0022     0.3563     0.7217     -0.0035      0.0051
# =================================================================================
#
# F-test for Poolability: 5.8224
# P-value: 0.0000
# Distribution: F(127,1850)
#
# Included effects: Entity, Time
#
# 随机效应模型结果:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.0128
# Estimator:              RandomEffects   R-squared (Between):              0.2592
# No. Observations:                1989   R-squared (Within):           -9.083e-05
# Date:                Sun, Mar 16 2025   R-squared (Overall):              0.0128
# Time:                        00:47:47   Log-likelihood                    4487.2
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2.3279
# Entities:                         111   P-value                           0.0077
# Avg Obs:                       17.919   Distribution:                 F(11,1977)
# Min Obs:                       12.000
# Max Obs:                       18.000   F-statistic (robust):             2.9131
#                                         P-value                           0.0008
# Time periods:                      18   Distribution:                 F(11,1977)
# Avg Obs:                       110.50
# Min Obs:                       108.00
# Max Obs:                       111.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const            -0.0089     0.0178    -0.4995     0.6175     -0.0438      0.0260
# avg_sentiment     0.0094     0.0043     2.1972     0.0281      0.0010      0.0178
# sentiment_std    -0.0042     0.0120    -0.3491     0.7270     -0.0277      0.0193
# avg_intensity     0.0170     0.0191     0.8919     0.3726     -0.0204      0.0544
# comment_count  3.505e-06  3.822e-06     0.9169     0.3593  -3.991e-06     1.1e-05
# close          3.371e-06  1.893e-06     1.7812     0.0750  -3.406e-07   7.083e-06
# volume        -1.014e-09  4.239e-10    -2.3917     0.0169  -1.845e-09  -1.825e-10
# amount        -1.092e-12   3.88e-13    -2.8144     0.0049  -1.853e-12   -3.31e-13
# amplitude         0.0006     0.0005     1.2244     0.2209     -0.0004      0.0016
# pct_change       -0.0003     0.0003    -0.8785     0.3798     -0.0009      0.0003
# price_change    6.35e-05     0.0001     0.4486     0.6538     -0.0002      0.0003
# turnover_rate     0.0004     0.0005     0.7938     0.4274     -0.0006      0.0014
# =================================================================================
#                        Model Comparison
# =============================================================
#                                         FE                 RE
# -------------------------------------------------------------
# Dep. Variable               forward_ret_1d     forward_ret_1d
# Estimator                         PanelOLS      RandomEffects
# No. Observations                      1989               1989
# Cov. Est.                        Clustered          Clustered
# R-squared                           0.0594             0.0128
# R-Squared (Within)                  0.0738         -9.083e-05
# R-Squared (Between)                -480.88             0.2592
# R-Squared (Overall)                -23.929             0.0128
# F-statistic                         10.627             2.3279
# P-value (F-stat)                    0.0000             0.0077
# =====================     ================   ================
# const                              0.0453*            -0.0089
#                                   (1.8145)          (-0.4995)
# avg_sentiment                     0.0101**           0.0094**
#                                   (2.2496)           (2.1972)
# sentiment_std                       0.0079            -0.0042
#                                   (0.6725)          (-0.3491)
# avg_intensity                       0.0091             0.0170
#                                   (0.4496)           (0.8919)
# comment_count                   -7.357e-06          3.505e-06
#                                  (-0.9427)           (0.9169)
# close                           -0.0008***         3.371e-06*
#                                  (-3.2394)           (1.7812)
# volume                          -2.762e-09       -1.014e-09**
#                                  (-1.2280)          (-2.3917)
# amount                          -1.832e-12      -1.092e-12***
#                                  (-1.3258)          (-2.8144)
# amplitude                         -0.0012*             0.0006
#                                  (-1.8914)           (1.2244)
# pct_change                          0.0001            -0.0003
#                                   (0.3219)          (-0.8785)
# price_change                       0.0003*           6.35e-05
#                                   (1.6512)           (0.4486)
# turnover_rate                       0.0008             0.0004
#                                   (0.3563)           (0.7938)
# ======================= ================== ==================
# Effects                             Entity
#                                       Time
# -------------------------------------------------------------
#
# T-stats reported in parentheses
#
# Hausman检验结果:
# 统计量: 105.2309
# P值: 0.0000
# 结论: 拒绝随机效应，使用固定效应
#
# 医药生物行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.1838
# Estimator:                   PanelOLS   R-squared (Between):             -1123.9
# No. Observations:                 286   R-squared (Within):               0.2221
# Date:                Sun, Mar 16 2025   R-squared (Overall):             -62.594
# Time:                        00:47:48   Log-likelihood                    773.34
# Cov. Estimator:             Clustered
#                                         F-statistic:                      4.9530
# Entities:                          16   P-value                           0.0000
# Avg Obs:                       17.875   Distribution:                  F(11,242)
# Min Obs:                       16.000
# Max Obs:                       18.000   F-statistic (robust):             89.964
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(11,242)
# Avg Obs:                       15.889
# Min Obs:                       15.000
# Max Obs:                       16.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.1620     0.0864     1.8755     0.0619     -0.0081      0.3322
# avg_sentiment     0.0146     0.0055     2.6545     0.0085      0.0038      0.0255
# sentiment_std    -0.0057     0.0168    -0.3398     0.7343     -0.0387      0.0273
# avg_intensity     0.0336     0.0310     1.0845     0.2792     -0.0275      0.0947
# comment_count   3.74e-06  2.739e-05     0.1365     0.8915  -5.022e-05    5.77e-05
# close            -0.0031     0.0012    -2.6322     0.0090     -0.0054     -0.0008
# volume        -3.496e-08  6.476e-09    -5.3979     0.0000  -4.772e-08   -2.22e-08
# amount         1.084e-11  4.621e-12     2.3467     0.0197   1.742e-12   1.995e-11
# amplitude         0.0015     0.0010     1.4865     0.1385     -0.0005      0.0036
# pct_change        0.0003     0.0005     0.6200     0.5358     -0.0007      0.0013
# price_change     -0.0017     0.0004    -4.0195     0.0001     -0.0025     -0.0009
# turnover_rate    -0.0071     0.0013    -5.3251     0.0000     -0.0098     -0.0045
# =================================================================================
#
# F-test for Poolability: 9.7824
# P-value: 0.0000
# Distribution: F(32,242)
#
# Included effects: Entity, Time
# 房地产行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.1629
# Estimator:                   PanelOLS   R-squared (Between):             -2113.4
# No. Observations:                 198   R-squared (Within):               0.1641
# Date:                Sun, Mar 16 2025   R-squared (Overall):             -34.724
# Time:                        00:47:48   Log-likelihood                    546.26
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2.8137
# Entities:                          78   P-value                           0.0022
# Avg Obs:                       2.5385   Distribution:                  F(11,159)
# Min Obs:                       0.0000
# Max Obs:                       18.000   F-statistic (robust):          1.566e+14
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(11,159)
# Avg Obs:                       11.000
# Min Obs:                       11.000
# Max Obs:                       11.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.0730     0.1169     0.6242     0.5334     -0.1579      0.3038
# avg_sentiment     0.0027     0.0064     0.4264     0.6704     -0.0099      0.0154
# sentiment_std     0.0267     0.0148     1.8087     0.0724     -0.0025      0.0559
# avg_intensity     0.0845     0.0444     1.9007     0.0592     -0.0033      0.1722
# comment_count -2.031e-06   2.26e-05    -0.0899     0.9285  -4.666e-05    4.26e-05
# close            -0.0242     0.0158    -1.5246     0.1293     -0.0555      0.0071
# volume         1.216e-08  1.029e-08     1.1815     0.2392  -8.165e-09   3.248e-08
# amount        -1.319e-11  1.101e-11    -1.1975     0.2329  -3.494e-11   8.562e-12
# amplitude        -0.0006     0.0020    -0.3101     0.7569     -0.0045      0.0033
# pct_change       -0.0020     0.0007    -3.0256     0.0029     -0.0033     -0.0007
# price_change      0.0102     0.0072     1.4107     0.1603     -0.0041      0.0245
# turnover_rate    -0.0031     0.0019    -1.6203     0.1072     -0.0070      0.0007
# =================================================================================
#
# F-test for Poolability: 6.6785
# P-value: 0.0000
# Distribution: F(27,159)
#
# Included effects: Entity, Time
#
# 有色金属行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.1923
# Estimator:                   PanelOLS   R-squared (Between):             -400.15
# No. Observations:                 270   R-squared (Within):               0.1954
# Date:                Sun, Mar 16 2025   R-squared (Overall):             -20.024
# Time:                        00:47:48   Log-likelihood                    813.05
# Cov. Estimator:             Clustered
#                                         F-statistic:                      4.9125
# Entities:                         110   P-value                           0.0000
# Avg Obs:                       2.4545   Distribution:                  F(11,227)
# Min Obs:                       0.0000
# Max Obs:                       18.000   F-statistic (robust):             96.512
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(11,227)
# Avg Obs:                       15.000
# Min Obs:                       15.000
# Max Obs:                       15.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.2296     0.1259     1.8231     0.0696     -0.0186      0.4777
# avg_sentiment     0.0208     0.0146     1.4259     0.1553     -0.0079      0.0494
# sentiment_std    -0.0776     0.0551    -1.4076     0.1606     -0.1862      0.0310
# avg_intensity    -0.0160     0.0457    -0.3511     0.7258     -0.1060      0.0740
# comment_count -3.773e-06  2.512e-05    -0.1502     0.8807  -5.326e-05   4.572e-05
# close            -0.0084     0.0062    -1.3614     0.1747     -0.0205      0.0038
# volume        -8.185e-09  5.085e-09    -1.6096     0.1089  -1.821e-08   1.835e-09
# amount         1.129e-11  4.302e-12     2.6240     0.0093   2.812e-12   1.977e-11
# amplitude       6.25e-05     0.0014     0.0459     0.9634     -0.0026      0.0027
# pct_change        0.0009     0.0011     0.8407     0.4014     -0.0013      0.0031
# price_change     -0.0195     0.0038    -5.1683     0.0000     -0.0269     -0.0121
# turnover_rate     0.0013     0.0041     0.3139     0.7539     -0.0068      0.0094
# =================================================================================
#
# F-test for Poolability: 7.3897
# P-value: 0.0000
# Distribution: F(31,227)
#
# Included effects: Entity, Time
#
# 电子行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.1042
# Estimator:                   PanelOLS   R-squared (Between):             -135.65
# No. Observations:                 252   R-squared (Within):               0.0380
# Date:                Sun, Mar 16 2025   R-squared (Overall):             -3.4157
# Time:                        00:47:48   Log-likelihood                    617.03
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2.2199
# Entities:                         109   P-value                           0.0146
# Avg Obs:                       2.3119   Distribution:                  F(11,210)
# Min Obs:                       0.0000
# Max Obs:                       18.000   F-statistic (robust):             64.188
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(11,210)
# Avg Obs:                       14.000
# Min Obs:                       14.000
# Max Obs:                       14.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const            -0.0121     0.0925    -0.1305     0.8963     -0.1944      0.1703
# avg_sentiment     0.0164     0.0125     1.3153     0.1898     -0.0082      0.0410
# sentiment_std    -0.1954     0.0737    -2.6521     0.0086     -0.3406     -0.0501
# avg_intensity     0.2586     0.0911     2.8371     0.0050      0.0789      0.4382
# comment_count  1.723e-05  2.271e-05     0.7586     0.4489  -2.754e-05   6.199e-05
# close            -0.0005     0.0003    -1.8388     0.0674     -0.0010   3.428e-05
# volume         8.054e-09  3.548e-09     2.2703     0.0242   1.061e-09   1.505e-08
# amount        -4.909e-12  2.518e-12    -1.9497     0.0525  -9.872e-12    5.44e-14
# amplitude        -0.0008     0.0008    -0.9616     0.3374     -0.0023      0.0008
# pct_change        0.0008     0.0006     1.3185     0.1888     -0.0004      0.0020
# price_change     -0.0002     0.0003    -0.4847     0.6284     -0.0008      0.0005
# turnover_rate     0.0030     0.0021     1.3814     0.1686     -0.0013      0.0072
# =================================================================================
#
# F-test for Poolability: 8.6551
# P-value: 0.0000
# Distribution: F(30,210)
#
# Included effects: Entity, Time
#
# 电气设备行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.3508
# Estimator:                   PanelOLS   R-squared (Between):             -371.15
# No. Observations:                 198   R-squared (Within):               0.2262
# Date:                Sun, Mar 16 2025   R-squared (Overall):             -11.888
# Time:                        00:47:48   Log-likelihood                    534.02
# Cov. Estimator:             Clustered
#                                         F-statistic:                      7.8115
# Entities:                          93   P-value                           0.0000
# Avg Obs:                       2.1290   Distribution:                  F(11,159)
# Min Obs:                       0.0000
# Max Obs:                       18.000   F-statistic (robust):          2.522e+15
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(11,159)
# Avg Obs:                       11.000
# Min Obs:                       11.000
# Max Obs:                       11.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.0092     0.1282     0.0719     0.9428     -0.2440      0.2624
# avg_sentiment     0.0339     0.0222     1.5263     0.1289     -0.0100      0.0779
# sentiment_std    -0.0031     0.0855    -0.0363     0.9711     -0.1720      0.1658
# avg_intensity     0.0658     0.1086     0.6055     0.5457     -0.1487      0.2802
# comment_count -5.389e-06  7.922e-06    -0.6803     0.4973  -2.104e-05   1.026e-05
# close            -0.0007  9.159e-05    -7.7940     0.0000     -0.0009     -0.0005
# volume        -8.871e-09  8.726e-09    -1.0167     0.3108   -2.61e-08   8.362e-09
# amount        -3.962e-12  1.635e-12    -2.4235     0.0165  -7.191e-12  -7.333e-13
# amplitude        -0.0033     0.0015    -2.1811     0.0306     -0.0063     -0.0003
# pct_change       -0.0016     0.0012    -1.2993     0.1957     -0.0040      0.0008
# price_change      0.0006     0.0006     1.0114     0.3133     -0.0005      0.0017
# turnover_rate     0.0122     0.0006     18.907     0.0000      0.0109      0.0135
# =================================================================================
#
# F-test for Poolability: 7.9281
# P-value: 0.0000
# Distribution: F(27,159)
#
# Included effects: Entity, Time
# 计算机行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.1548
# Estimator:                   PanelOLS   R-squared (Between):             -125.08
# No. Observations:                 246   R-squared (Within):               0.1428
# Date:                Sun, Mar 16 2025   R-squared (Overall):             -7.6512
# Time:                        00:47:48   Log-likelihood                    547.63
# Cov. Estimator:             Clustered
#                                         F-statistic:                      3.3955
# Entities:                         111   P-value                           0.0002
# Avg Obs:                       2.2162   Distribution:                  F(11,204)
# Min Obs:                       0.0000
# Max Obs:                       18.000   F-statistic (robust):             79.066
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(11,204)
# Avg Obs:                       13.667
# Min Obs:                       13.000
# Max Obs:                       14.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.1657     0.0689     2.4053     0.0171      0.0299      0.3015
# avg_sentiment     0.0400     0.0194     2.0670     0.0400      0.0018      0.0782
# sentiment_std    -0.0968     0.0541    -1.7898     0.0750     -0.2033      0.0098
# avg_intensity     0.0523     0.0908     0.5762     0.5651     -0.1267      0.2313
# comment_count -2.659e-05  2.935e-05    -0.9060     0.3660  -8.445e-05   3.127e-05
# close            -0.0014     0.0002    -6.4192     0.0000     -0.0019     -0.0010
# volume        -6.954e-09  5.763e-09    -1.2067     0.2290  -1.832e-08   4.409e-09
# amount          7.81e-13   2.35e-12     0.3324     0.7399  -3.851e-12   5.414e-12
# amplitude        -0.0008     0.0016    -0.5262     0.5993     -0.0039      0.0023
# pct_change       -0.0006     0.0007    -0.7691     0.4427     -0.0020      0.0009
# price_change      0.0001     0.0002     0.6702     0.5035     -0.0003      0.0006
# turnover_rate    -0.0004     0.0015    -0.2843     0.7765     -0.0034      0.0025
# =================================================================================
#
# F-test for Poolability: 9.1608
# P-value: 0.0000
# Distribution: F(30,204)
#
# Included effects: Entity, Time
#
# 银行行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.1449
# Estimator:                   PanelOLS   R-squared (Between):             -1448.5
# No. Observations:                 269   R-squared (Within):               0.0650
# Date:                Sun, Mar 16 2025   R-squared (Overall):             -45.751
# Time:                        00:47:48   Log-likelihood                    1050.1
# Cov. Estimator:             Clustered
#                                         F-statistic:                      3.4812
# Entities:                          15   P-value                           0.0002
# Avg Obs:                       17.933   Distribution:                  F(11,226)
# Min Obs:                       17.000
# Max Obs:                       18.000   F-statistic (robust):             8.8354
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(11,226)
# Avg Obs:                       14.944
# Min Obs:                       14.000
# Max Obs:                       15.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.0535     0.0238     2.2470     0.0256      0.0066      0.1004
# avg_sentiment    -0.0038     0.0017    -2.2016     0.0287     -0.0072     -0.0004
# sentiment_std     0.0079     0.0074     1.0676     0.2869     -0.0067      0.0224
# avg_intensity    -0.0001     0.0168    -0.0086     0.9932     -0.0333      0.0330
# comment_count  1.925e-06  3.221e-06     0.5977     0.5507  -4.422e-06   8.272e-06
# close            -0.0059     0.0020    -2.9581     0.0034     -0.0098     -0.0020
# volume         1.119e-09  1.814e-09     0.6168     0.5380  -2.456e-09   4.693e-09
# amount        -2.429e-12  3.278e-12    -0.7409     0.4595  -8.889e-12   4.031e-12
# amplitude        -0.0034     0.0015    -2.3240     0.0210     -0.0063     -0.0005
# pct_change       -0.0007     0.0012    -0.5802     0.5623     -0.0030      0.0016
# price_change      0.0034     0.0028     1.1991     0.2318     -0.0022      0.0090
# turnover_rate     0.0052     0.0029     1.7643     0.0790     -0.0006      0.0109
# =================================================================================
#
# F-test for Poolability: 14.046
# P-value: 0.0000
# Distribution: F(31,226)
#
# Included effects: Entity, Time
#
# 食品饮料行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.0841
# Estimator:                   PanelOLS   R-squared (Between):             -29.157
# No. Observations:                 270   R-squared (Within):               0.1054
# Date:                Sun, Mar 16 2025   R-squared (Overall):             -0.7808
# Time:                        00:47:48   Log-likelihood                    828.78
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1.8958
# Entities:                         104   P-value                           0.0409
# Avg Obs:                       2.5962   Distribution:                  F(11,227)
# Min Obs:                       0.0000
# Max Obs:                       18.000   F-statistic (robust):             7.2687
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(11,227)
# Avg Obs:                       15.000
# Min Obs:                       15.000
# Max Obs:                       15.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const            -0.0033     0.0286    -0.1146     0.9089     -0.0596      0.0531
# avg_sentiment     0.0097     0.0086     1.1169     0.2652     -0.0074      0.0267
# sentiment_std     0.0346     0.0144     2.4074     0.0169      0.0063      0.0629
# avg_intensity    -0.0138     0.0322    -0.4291     0.6683     -0.0773      0.0496
# comment_count  1.942e-05  1.899e-05     1.0224     0.3077  -1.801e-05   5.684e-05
# close         -4.241e-05  6.028e-05    -0.7035     0.4824     -0.0002   7.637e-05
# volume        -1.137e-08  1.709e-08    -0.6654     0.5065  -4.503e-08    2.23e-08
# amount        -9.753e-13   1.11e-12    -0.8788     0.3804  -3.162e-12   1.211e-12
# amplitude      4.717e-05     0.0016     0.0301     0.9760     -0.0030      0.0031
# pct_change       -0.0010     0.0010    -0.9681     0.3340     -0.0030      0.0010
# price_change   1.863e-05  7.214e-05     0.2583     0.7964     -0.0001      0.0002
# turnover_rate    -0.0056     0.0017    -3.2648     0.0013     -0.0089     -0.0022
# =================================================================================
#
# F-test for Poolability: 5.0807
# P-value: 0.0000
# Distribution: F(31,227)
#
# Included effects: Entity, Time
