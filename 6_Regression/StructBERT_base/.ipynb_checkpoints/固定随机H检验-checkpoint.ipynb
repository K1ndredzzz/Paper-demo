# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests
from linearmodels import PanelOLS, RandomEffects
from linearmodels.panel import compare
from scipy import stats
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv('stock_daily_sentiment.csv')
df['date'] = pd.to_datetime(df['date'])
df['stock_code'] = df['stock_code'].astype(str).str.zfill(6)

df = df.set_index(['stock_code', 'date'])

# 定义因变量和自变量
y = df['forward_ret_1d']  # 可以改为forward_ret_3d或forward_ret_5d
X = df[['avg_sentiment', 'sentiment_std', 
             'avg_intensity', 'comment_count',
             'close', 'volume', 'amount', 'amplitude',
             'pct_change', 'price_change', 'turnover_rate']]
X = sm.add_constant(X)

# 1. 固定效应模型
fixed_effects = PanelOLS(y, X, entity_effects=True, time_effects=True)
fe_results = fixed_effects.fit(cov_type='clustered', cluster_entity=True)
print("固定效应模型结果:")
print(fe_results)

# 2. 随机效应模型
random_effects = RandomEffects(y, X)
re_results = random_effects.fit(cov_type='clustered', cluster_entity=True)
print("\n随机效应模型结果:")
print(re_results)

comparison = compare({'FE': fe_results, 'RE': re_results}, stars = True)
print(comparison)

# 3. Hausman检验
def hausman_test(fe_model, re_model):
    # 提取系数和协方差矩阵
    b_fe = fe_model.params
    b_re = re_model.params
    
    # 去除常数项后的系数差
    b_diff = b_fe - b_re
    
    # 计算协方差矩阵差
    var_fe = fe_model.cov
    var_re = re_model.cov
    var_diff = var_fe - var_re
    
    # Hausman统计量
    H = np.dot(np.dot(b_diff.T, np.linalg.inv(var_diff)), b_diff)
    
    # 自由度(参数个数)
    df = len(b_fe)
    
    # p值
    p_value = 1 - stats.chi2.cdf(H, df)
    
    return H, p_value

H_stat, p_val = hausman_test(fe_results, re_results)
print("\nHausman检验结果:")
print(f"统计量: {H_stat:.4f}")
print(f"P值: {p_val:.4f}")
print("结论:", "拒绝随机效应，使用固定效应" if p_val < 0.05 else "接受随机效应")

# 可以添加行业固定效应
# 如果需要控制行业效应，在数据中加入行业虚拟变量
# 添加行业虚拟变量，但删除一个类别避免完全共线性
# 按市值大小分组回归
for group in df.groupby('industry'):
    industry_data = group[1]
    y = industry_data['forward_ret_1d']
    X = industry_data[['avg_sentiment', 'sentiment_std', 
             'avg_intensity', 'comment_count',
             'close', 'volume', 'amount', 'amplitude',
             'pct_change', 'price_change', 'turnover_rate']]
    X = sm.add_constant(X)
    
    fixed_effects = PanelOLS(y, X, entity_effects=True, time_effects=True)
    fe_results = fixed_effects.fit(cov_type='clustered', cluster_entity=True)
    print(f"\n{group[0]}行业的回归结果:")
    print(fe_results)
    #export_results(fe_results, f'{group[0]}fixed_effects_results.xlsx')

'''
# 输出回归结果到Excel（可选）
def export_results(results, filename):
    # 获取置信区间DataFrame
    conf_int = results.conf_int()
    
    # 创建摘要DataFrame
    summary_df = pd.DataFrame({
        'coefficient': results.params,
        'std_error': results.std_errors,
        't_stat': results.tstats,
        'p_value': results.pvalues,
        'conf_int_lower': conf_int.iloc[:, 0],  # 使用iloc正确获取第一列
        'conf_int_upper': conf_int.iloc[:, 1]   # 使用iloc正确获取第二列
    })
    summary_df.to_excel(filename)
export_results(re_results, 'random_effects_results.xlsx')
'''
# Out:
# 固定效应模型结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.0579
# Estimator:                   PanelOLS   R-squared (Between):             -483.33
# No. Observations:                1989   R-squared (Within):               0.0722
# Date:                Sun, Mar 16 2025   R-squared (Overall):             -24.053
# Time:                        14:34:19   Log-likelihood                    4820.1
# Cov. Estimator:             Clustered
#                                         F-statistic:                      10.345
# Entities:                         111   P-value                           0.0000
# Avg Obs:                       17.919   Distribution:                 F(11,1850)
# Min Obs:                       12.000
# Max Obs:                       18.000   F-statistic (robust):             4.6868
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                 F(11,1850)
# Avg Obs:                       110.50
# Min Obs:                       108.00
# Max Obs:                       111.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.0590     0.0195     3.0195     0.0026      0.0207      0.0973
# avg_sentiment     0.0146     0.0068     2.1499     0.0317      0.0013      0.0279
# sentiment_std    -0.0134     0.0236    -0.5660     0.5715     -0.0597      0.0329
# avg_intensity     0.0185     0.0261     0.7081     0.4790     -0.0327      0.0697
# comment_count  -7.92e-06  7.871e-06    -1.0062     0.3144  -2.336e-05   7.517e-06
# close            -0.0008     0.0003    -3.2478     0.0012     -0.0013     -0.0003
# volume         -2.74e-09  2.256e-09    -1.2144     0.2247  -7.165e-09   1.685e-09
# amount        -1.774e-12   1.38e-12    -1.2857     0.1987  -4.481e-12   9.324e-13
# amplitude        -0.0013     0.0007    -1.9648     0.0496     -0.0026  -2.356e-06
# pct_change        0.0002     0.0003     0.5090     0.6108     -0.0005      0.0008
# price_change      0.0003     0.0002     1.5137     0.1303  -8.464e-05      0.0007
# turnover_rate     0.0008     0.0022     0.3600     0.7189     -0.0035      0.0051
# =================================================================================
#
# F-test for Poolability: 5.8001
# P-value: 0.0000
# Distribution: F(127,1850)
#
# Included effects: Entity, Time
#
# 随机效应模型结果:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.0123
# Estimator:              RandomEffects   R-squared (Between):              0.2749
# No. Observations:                1989   R-squared (Within):              -0.0013
# Date:                Sun, Mar 16 2025   R-squared (Overall):              0.0123
# Time:                        14:34:19   Log-likelihood                    4486.7
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2.2405
# Entities:                         111   P-value                           0.0106
# Avg Obs:                       17.919   Distribution:                 F(11,1977)
# Min Obs:                       12.000
# Max Obs:                       18.000   F-statistic (robust):             2.7007
#                                         P-value                           0.0019
# Time periods:                      18   Distribution:                 F(11,1977)
# Avg Obs:                       110.50
# Min Obs:                       108.00
# Max Obs:                       111.00
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const            -0.0095     0.0095    -0.9996     0.3176     -0.0281      0.0091
# avg_sentiment     0.0119     0.0069     1.7241     0.0848     -0.0016      0.0255
# sentiment_std    -0.0066     0.0216    -0.3039     0.7612     -0.0488      0.0357
# avg_intensity     0.0267     0.0244     1.0922     0.2749     -0.0212      0.0745
# comment_count  2.057e-06  3.871e-06     0.5313     0.5953  -5.535e-06   9.649e-06
# close          2.645e-06  1.904e-06     1.3888     0.1651   -1.09e-06    6.38e-06
# volume        -9.634e-10  4.365e-10    -2.2073     0.0274  -1.819e-09  -1.074e-10
# amount        -1.041e-12   3.98e-13    -2.6161     0.0090  -1.822e-12  -2.607e-13
# amplitude         0.0006     0.0005     1.2940     0.1958     -0.0003      0.0016
# pct_change       -0.0002     0.0003    -0.8025     0.4224     -0.0008      0.0003
# price_change   4.592e-05     0.0001     0.3194     0.7495     -0.0002      0.0003
# turnover_rate     0.0004     0.0005     0.7333     0.4634     -0.0007      0.0014
# =================================================================================
#                        Model Comparison
# =============================================================
#                                         FE                 RE
# -------------------------------------------------------------
# Dep. Variable               forward_ret_1d     forward_ret_1d
# Estimator                         PanelOLS      RandomEffects
# No. Observations                      1989               1989
# Cov. Est.                        Clustered          Clustered
# R-squared                           0.0579             0.0123
# R-Squared (Within)                  0.0722            -0.0013
# R-Squared (Between)                -483.33             0.2749
# R-Squared (Overall)                -24.053             0.0123
# F-statistic                         10.345             2.2405
# P-value (F-stat)                    0.0000             0.0106
# =====================     ================   ================
# const                            0.0590***            -0.0095
#                                   (3.0195)          (-0.9996)
# avg_sentiment                     0.0146**            0.0119*
#                                   (2.1499)           (1.7241)
# sentiment_std                      -0.0134            -0.0066
#                                  (-0.5660)          (-0.3039)
# avg_intensity                       0.0185             0.0267
#                                   (0.7081)           (1.0922)
# comment_count                    -7.92e-06          2.057e-06
#                                  (-1.0062)           (0.5313)
# close                           -0.0008***          2.645e-06
#                                  (-3.2478)           (1.3888)
# volume                           -2.74e-09       -9.634e-10**
#                                  (-1.2144)          (-2.2073)
# amount                          -1.774e-12      -1.041e-12***
#                                  (-1.2857)          (-2.6161)
# amplitude                        -0.0013**             0.0006
#                                  (-1.9648)           (1.2940)
# pct_change                          0.0002            -0.0002
#                                   (0.5090)          (-0.8025)
# price_change                        0.0003          4.592e-05
#                                   (1.5137)           (0.3194)
# turnover_rate                       0.0008             0.0004
#                                   (0.3600)           (0.7333)
# ======================= ================== ==================
# Effects                             Entity
#                                       Time
# -------------------------------------------------------------
#
# T-stats reported in parentheses
#
# Hausman检验结果:
# 统计量: -35.6313
# P值: 1.0000
# 结论: 接受随机效应
#
# 医药生物行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.2013
# Estimator:                   PanelOLS   R-squared (Between):             -1149.7
# No. Observations:                 286   R-squared (Within):               0.2356
# Date:                Sun, Mar 16 2025   R-squared (Overall):             -64.028
# Time:                        14:34:19   Log-likelihood                    776.45
# Cov. Estimator:             Clustered
#                                         F-statistic:                      5.5454
# Entities:                          16   P-value                           0.0000
# Avg Obs:                       17.875   Distribution:                  F(11,242)
# Min Obs:                       16.000
# Max Obs:                       18.000   F-statistic (robust):             57.923
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(11,242)
# Avg Obs:                       15.889
# Min Obs:                       15.000
# Max Obs:                       16.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.2187     0.0646     3.3869     0.0008      0.0915      0.3458
# avg_sentiment     0.0354     0.0146     2.4255     0.0160      0.0067      0.0642
# sentiment_std    -0.0755     0.0326    -2.3151     0.0214     -0.1398     -0.0113
# avg_intensity     0.0391     0.0455     0.8597     0.3908     -0.0505      0.1288
# comment_count   4.83e-06  2.736e-05     0.1765     0.8600  -4.907e-05   5.873e-05
# close            -0.0031     0.0011    -2.8801     0.0043     -0.0052     -0.0010
# volume        -3.496e-08  6.067e-09    -5.7625     0.0000  -4.691e-08  -2.301e-08
# amount         1.021e-11  4.296e-12     2.3761     0.0183   1.745e-12   1.867e-11
# amplitude         0.0015     0.0011     1.3746     0.1705     -0.0006      0.0035
# pct_change     6.996e-05     0.0006     0.1224     0.9027     -0.0011      0.0012
# price_change     -0.0015     0.0003    -4.3501     0.0000     -0.0022     -0.0008
# turnover_rate    -0.0069     0.0016    -4.4787     0.0000     -0.0100     -0.0039
# =================================================================================
#
# F-test for Poolability: 9.9022
# P-value: 0.0000
# Distribution: F(32,242)
#
# Included effects: Entity, Time
# 房地产行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.1495
# Estimator:                   PanelOLS   R-squared (Between):             -2030.3
# No. Observations:                 198   R-squared (Within):               0.1592
# Date:                Sun, Mar 16 2025   R-squared (Overall):             -33.357
# Time:                        14:34:20   Log-likelihood                    544.68
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2.5414
# Entities:                          78   P-value                           0.0055
# Avg Obs:                       2.5385   Distribution:                  F(11,159)
# Min Obs:                       0.0000
# Max Obs:                       18.000   F-statistic (robust):         -1.944e+15
#                                         P-value                           1.0000
# Time periods:                      18   Distribution:                  F(11,159)
# Avg Obs:                       11.000
# Min Obs:                       11.000
# Max Obs:                       11.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.1486     0.1115     1.3328     0.1845     -0.0716      0.3687
# avg_sentiment    -0.0025     0.0093    -0.2651     0.7913     -0.0208      0.0159
# sentiment_std     0.0412     0.0099     4.1589     0.0001      0.0216      0.0608
# avg_intensity    -0.0032     0.0483    -0.0668     0.9468     -0.0986      0.0921
# comment_count -2.001e-06  2.169e-05    -0.0923     0.9266  -4.483e-05   4.083e-05
# close            -0.0239     0.0158    -1.5111     0.1327     -0.0550      0.0073
# volume         1.225e-08  1.067e-08     1.1480     0.2527  -8.823e-09   3.332e-08
# amount        -1.333e-11  1.147e-11    -1.1630     0.2466  -3.598e-11    9.31e-12
# amplitude        -0.0006     0.0019    -0.3280     0.7434     -0.0044      0.0032
# pct_change       -0.0019     0.0006    -2.9022     0.0042     -0.0031     -0.0006
# price_change      0.0076     0.0080     0.9560     0.3405     -0.0081      0.0234
# turnover_rate    -0.0035     0.0023    -1.5544     0.1221     -0.0080      0.0010
# =================================================================================
#
# F-test for Poolability: 6.3395
# P-value: 0.0000
# Distribution: F(27,159)
#
# Included effects: Entity, Time
#
# 有色金属行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.1776
# Estimator:                   PanelOLS   R-squared (Between):             -432.99
# No. Observations:                 270   R-squared (Within):               0.1804
# Date:                Sun, Mar 16 2025   R-squared (Overall):             -21.697
# Time:                        14:34:20   Log-likelihood                    810.62
# Cov. Estimator:             Clustered
#                                         F-statistic:                      4.4569
# Entities:                         110   P-value                           0.0000
# Avg Obs:                       2.4545   Distribution:                  F(11,227)
# Min Obs:                       0.0000
# Max Obs:                       18.000   F-statistic (robust):             115.31
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(11,227)
# Avg Obs:                       15.000
# Min Obs:                       15.000
# Max Obs:                       15.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.1454     0.1069     1.3600     0.1752     -0.0653      0.3560
# avg_sentiment     0.0234     0.0137     1.7106     0.0885     -0.0036      0.0503
# sentiment_std    -0.0733     0.0511    -1.4344     0.1528     -0.1741      0.0274
# avg_intensity     0.0808     0.0455     1.7738     0.0774     -0.0090      0.1705
# comment_count -7.823e-07  2.703e-05    -0.0289     0.9769  -5.404e-05   5.248e-05
# close            -0.0087     0.0062    -1.4111     0.1596     -0.0209      0.0035
# volume        -8.188e-09  4.963e-09    -1.6498     0.1004  -1.797e-08   1.592e-09
# amount         1.094e-11  4.728e-12     2.3146     0.0215   1.627e-12   2.026e-11
# amplitude     -6.745e-05     0.0014    -0.0468     0.9627     -0.0029      0.0028
# pct_change        0.0012     0.0012     1.0706     0.2855     -0.0010      0.0035
# price_change     -0.0195     0.0039    -5.0508     0.0000     -0.0271     -0.0119
# turnover_rate     0.0016     0.0043     0.3628     0.7171     -0.0070      0.0101
# =================================================================================
#
# F-test for Poolability: 7.3913
# P-value: 0.0000
# Distribution: F(31,227)
#
# Included effects: Entity, Time
#
# 电子行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.0832
# Estimator:                   PanelOLS   R-squared (Between):             -144.38
# No. Observations:                 252   R-squared (Within):               0.0480
# Date:                Sun, Mar 16 2025   R-squared (Overall):             -3.6282
# Time:                        14:34:20   Log-likelihood                    614.12
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1.7332
# Entities:                         109   P-value                           0.0680
# Avg Obs:                       2.3119   Distribution:                  F(11,210)
# Min Obs:                       0.0000
# Max Obs:                       18.000   F-statistic (robust):             21.304
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(11,210)
# Avg Obs:                       14.000
# Min Obs:                       14.000
# Max Obs:                       14.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.0882     0.0555     1.5897     0.1134     -0.0212      0.1976
# avg_sentiment     0.0372     0.0210     1.7761     0.0772     -0.0041      0.0785
# sentiment_std    -0.2294     0.1032    -2.2227     0.0273     -0.4329     -0.0259
# avg_intensity     0.1852     0.1014     1.8262     0.0692     -0.0147      0.3850
# comment_count  1.912e-05  2.104e-05     0.9091     0.3643  -2.234e-05   6.059e-05
# close            -0.0005     0.0003    -1.8344     0.0680     -0.0010   3.765e-05
# volume          6.95e-09  3.463e-09     2.0071     0.0460   1.239e-10   1.378e-08
# amount        -5.608e-12  2.592e-12    -2.1631     0.0317  -1.072e-11  -4.973e-13
# amplitude        -0.0007     0.0008    -0.8973     0.3706     -0.0022      0.0008
# pct_change        0.0008     0.0007     1.2109     0.2273     -0.0005      0.0021
# price_change     -0.0003     0.0004    -0.7694     0.4425     -0.0010      0.0004
# turnover_rate     0.0030     0.0023     1.2906     0.1983     -0.0016      0.0076
# =================================================================================
#
# F-test for Poolability: 8.2310
# P-value: 0.0000
# Distribution: F(30,210)
#
# Included effects: Entity, Time
# 电气设备行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.3299
# Estimator:                   PanelOLS   R-squared (Between):             -353.63
# No. Observations:                 198   R-squared (Within):               0.2132
# Date:                Sun, Mar 16 2025   R-squared (Overall):             -11.329
# Time:                        14:34:20   Log-likelihood                    530.89
# Cov. Estimator:             Clustered
#                                         F-statistic:                      7.1174
# Entities:                          93   P-value                           0.0000
# Avg Obs:                       2.1290   Distribution:                  F(11,159)
# Min Obs:                       0.0000
# Max Obs:                       18.000   F-statistic (robust):         -9.662e+15
#                                         P-value                           1.0000
# Time periods:                      18   Distribution:                  F(11,159)
# Avg Obs:                       11.000
# Min Obs:                       11.000
# Max Obs:                       11.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.0619     0.0606     1.0215     0.3086     -0.0578      0.1816
# avg_sentiment    -0.0034     0.0313    -0.1070     0.9149     -0.0652      0.0585
# sentiment_std     0.0562     0.0924     0.6077     0.5442     -0.1263      0.2386
# avg_intensity    -0.0658     0.0806    -0.8159     0.4158     -0.2250      0.0935
# comment_count -3.881e-06  9.221e-06    -0.4208     0.6744  -2.209e-05   1.433e-05
# close            -0.0007     0.0001    -5.5180     0.0000     -0.0009     -0.0004
# volume        -1.003e-08  8.432e-09    -1.1891     0.2362  -2.668e-08   6.627e-09
# amount        -3.091e-12  1.344e-12    -2.2992     0.0228  -5.746e-12  -4.358e-13
# amplitude        -0.0029     0.0015    -1.9233     0.0562     -0.0059   7.851e-05
# pct_change       -0.0008     0.0012    -0.6843     0.4948     -0.0032      0.0016
# price_change      0.0005     0.0005     0.9043     0.3672     -0.0006      0.0016
# turnover_rate     0.0124     0.0010     13.004     0.0000      0.0105      0.0143
# =================================================================================
#
# F-test for Poolability: 7.7887
# P-value: 0.0000
# Distribution: F(27,159)
#
# Included effects: Entity, Time
#
# 计算机行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.1559
# Estimator:                   PanelOLS   R-squared (Between):             -124.26
# No. Observations:                 246   R-squared (Within):               0.1434
# Date:                Sun, Mar 16 2025   R-squared (Overall):             -7.5995
# Time:                        14:34:20   Log-likelihood                    547.81
# Cov. Estimator:             Clustered
#                                         F-statistic:                      3.4262
# Entities:                         111   P-value                           0.0002
# Avg Obs:                       2.2162   Distribution:                  F(11,204)
# Min Obs:                       0.0000
# Max Obs:                       18.000   F-statistic (robust):             43.659
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(11,204)
# Avg Obs:                       13.667
# Min Obs:                       13.000
# Max Obs:                       14.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.0875     0.0508     1.7225     0.0865     -0.0127      0.1878
# avg_sentiment     0.0499     0.0210     2.3775     0.0184      0.0085      0.0913
# sentiment_std    -0.0212     0.0728    -0.2913     0.7711     -0.1646      0.1223
# avg_intensity     0.0783     0.0830     0.9441     0.3463     -0.0852      0.2419
# comment_count -2.559e-05  2.854e-05    -0.8966     0.3710  -8.185e-05   3.068e-05
# close            -0.0014     0.0002    -6.9783     0.0000     -0.0018     -0.0010
# volume         -7.42e-09  5.909e-09    -1.2557     0.2106  -1.907e-08    4.23e-09
# amount         9.178e-13  2.432e-12     0.3774     0.7063  -3.878e-12   5.713e-12
# amplitude        -0.0008     0.0017    -0.4788     0.6326     -0.0043      0.0026
# pct_change       -0.0006     0.0008    -0.7074     0.4801     -0.0021      0.0010
# price_change      0.0001     0.0002     0.6842     0.4946     -0.0002      0.0005
# turnover_rate    -0.0004     0.0014    -0.2770     0.7821     -0.0032      0.0024
# =================================================================================
#
# F-test for Poolability: 9.3082
# P-value: 0.0000
# Distribution: F(30,204)
#
# Included effects: Entity, Time
#
# 银行行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.1430
# Estimator:                   PanelOLS   R-squared (Between):             -1455.7
# No. Observations:                 269   R-squared (Within):               0.0606
# Date:                Sun, Mar 16 2025   R-squared (Overall):             -45.983
# Time:                        14:34:20   Log-likelihood                    1049.8
# Cov. Estimator:             Clustered
#                                         F-statistic:                      3.4272
# Entities:                          15   P-value                           0.0002
# Avg Obs:                       17.933   Distribution:                  F(11,226)
# Min Obs:                       17.000
# Max Obs:                       18.000   F-statistic (robust):             8.3523
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(11,226)
# Avg Obs:                       14.944
# Min Obs:                       14.000
# Max Obs:                       15.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.0548     0.0213     2.5714     0.0108      0.0128      0.0969
# avg_sentiment    -0.0038     0.0026    -1.5015     0.1346     -0.0089      0.0012
# sentiment_std     0.0278     0.0187     1.4875     0.1383     -0.0090      0.0645
# avg_intensity    -0.0211     0.0138    -1.5294     0.1276     -0.0483      0.0061
# comment_count  2.998e-06  3.554e-06     0.8435     0.3998  -4.006e-06       1e-05
# close            -0.0059     0.0021    -2.7755     0.0060     -0.0100     -0.0017
# volume         1.299e-09  1.851e-09     0.7017     0.4836  -2.349e-09   4.947e-09
# amount        -3.003e-12  3.065e-12    -0.9797     0.3283  -9.044e-12   3.037e-12
# amplitude        -0.0032     0.0014    -2.3723     0.0185     -0.0059     -0.0005
# pct_change       -0.0006     0.0012    -0.5269     0.5988     -0.0030      0.0017
# price_change      0.0029     0.0028     1.0503     0.2947     -0.0026      0.0084
# turnover_rate     0.0056     0.0027     2.0971     0.0371      0.0003      0.0108
# =================================================================================
#
# F-test for Poolability: 14.087
# P-value: 0.0000
# Distribution: F(31,226)
#
# Included effects: Entity, Time
#
# 食品饮料行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.0532
# Estimator:                   PanelOLS   R-squared (Between):             -65.441
# No. Observations:                 270   R-squared (Within):               0.0955
# Date:                Sun, Mar 16 2025   R-squared (Overall):             -1.8893
# Time:                        14:34:20   Log-likelihood                    824.28
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1.1586
# Entities:                         104   P-value                           0.3173
# Avg Obs:                       2.5962   Distribution:                  F(11,227)
# Min Obs:                       0.0000
# Max Obs:                       18.000   F-statistic (robust):             3.2519
#                                         P-value                           0.0004
# Time periods:                      18   Distribution:                  F(11,227)
# Avg Obs:                       15.000
# Min Obs:                       15.000
# Max Obs:                       15.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.0198     0.0226     0.8766     0.3816     -0.0247      0.0642
# avg_sentiment     0.0051     0.0115     0.4445     0.6571     -0.0175      0.0277
# sentiment_std     0.0190     0.0290     0.6540     0.5138     -0.0382      0.0762
# avg_intensity    -0.0224     0.0325    -0.6883     0.4920     -0.0865      0.0417
# comment_count  1.643e-05  2.004e-05     0.8197     0.4133  -2.306e-05   5.592e-05
# close         -6.292e-05  6.485e-05    -0.9703     0.3329     -0.0002   6.486e-05
# volume        -9.475e-09  1.819e-08    -0.5209     0.6029  -4.532e-08   2.637e-08
# amount        -8.701e-13  1.183e-12    -0.7356     0.4627  -3.201e-12   1.461e-12
# amplitude      6.249e-05     0.0016     0.0396     0.9684     -0.0030      0.0032
# pct_change       -0.0007     0.0011    -0.6418     0.5217     -0.0029      0.0015
# price_change   3.151e-05  7.302e-05     0.4316     0.6664     -0.0001      0.0002
# turnover_rate    -0.0057     0.0020    -2.8244     0.0052     -0.0097     -0.0017
# =================================================================================
#
# F-test for Poolability: 4.7347
# P-value: 0.0000
# Distribution: F(31,227)
#
# Included effects: Entity, Time
