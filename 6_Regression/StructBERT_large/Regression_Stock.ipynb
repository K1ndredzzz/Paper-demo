# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests
from linearmodels import PanelOLS, RandomEffects
from linearmodels.panel import compare
from scipy import stats
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv('stock_daily_sentiment.csv')
df['date'] = pd.to_datetime(df['date'])
df['stock_code'] = df['stock_code'].astype(str).str.zfill(6)

df = df.set_index(['stock_code', 'date'])

# %%
df[df'sentiment_std'.isnull()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 df['sentiment_std'.isnull()]
#
# AttributeError: 'str' object has no attribute 'isnull'

# %%
All_Y = df[['open','close','high','low','volume','amount','amplitude','pct_change',
               'price_change','turnover_rate','idx_close', 'idx_volume', 'idx_amount', 'idx_pct_change','forward_ret_1d','forward_ret_3d','forward_ret_5d']]
All_X = df[['avg_sentiment','sentiment_std','positive_ratio','negative_ratio',
            'avg_intensity','comment_count','avg_positive_prob','avg_negative_prob',
            'sentiment_net','sentiment_consensus','ma_3d','std_3d',
            'sentiment_change_3d','ma_5d','std_5d','sentiment_change_5d',
            'ma_10d','std_10d','sentiment_change_10d']]
Sel_Y = df[['close','volume','amount','amplitude','pct_change',
               'price_change','turnover_rate','forward_ret_1d','forward_ret_3d','forward_ret_5d']]
Sel_X = df[['avg_sentiment'#,'positive_ratio'
               ,'sentiment_std',
            'avg_intensity','comment_count',
            'sentiment_consensus','ma_3d','std_3d',
            'sentiment_change_3d']]

# 计算相关性矩阵
corr_matrix = All_X.corr()

#print(corr_matrix)
# 找出高度相关的变量对(相关系数>0.8)
high_corr = np.where(np.abs(corr_matrix) > 0.6)
high_corr = [(corr_matrix.index[x], corr_matrix.columns[y], corr_matrix.iloc[x, y]) 
             for x, y in zip(*high_corr) if x != y and x < y]

# 查看高相关性的变量对
for var1, var2, corr in high_corr:
    print(f"{var1} - {var2}: {corr:.3f}")
# Out:
# avg_sentiment - positive_ratio: 0.965
# avg_sentiment - negative_ratio: -0.965
# avg_sentiment - avg_positive_prob: 1.000
# avg_sentiment - avg_negative_prob: -1.000
# avg_sentiment - sentiment_net: 0.965
# avg_sentiment - ma_3d: 0.777
# avg_sentiment - ma_5d: 0.719
# avg_sentiment - ma_10d: 0.676
# positive_ratio - negative_ratio: -1.000
# positive_ratio - avg_positive_prob: 0.965
# positive_ratio - avg_negative_prob: -0.965
# positive_ratio - sentiment_net: 1.000
# positive_ratio - ma_3d: 0.740
# positive_ratio - ma_5d: 0.683
# positive_ratio - ma_10d: 0.636
# negative_ratio - avg_positive_prob: -0.965
# negative_ratio - avg_negative_prob: 0.965
# negative_ratio - sentiment_net: -1.000
# negative_ratio - ma_3d: -0.740
# negative_ratio - ma_5d: -0.683
# negative_ratio - ma_10d: -0.636
# avg_positive_prob - avg_negative_prob: -1.000
# avg_positive_prob - sentiment_net: 0.965
# avg_positive_prob - ma_3d: 0.777
# avg_positive_prob - ma_5d: 0.719
# avg_positive_prob - ma_10d: 0.676
# avg_negative_prob - sentiment_net: -0.965
# avg_negative_prob - ma_3d: -0.777
# avg_negative_prob - ma_5d: -0.719
# avg_negative_prob - ma_10d: -0.676
# sentiment_net - ma_3d: 0.740
# sentiment_net - ma_5d: 0.683
# sentiment_net - ma_10d: 0.636
# ma_3d - ma_5d: 0.934
# ma_3d - ma_10d: 0.878
# std_3d - std_5d: 0.819
# std_3d - std_10d: 0.725
# ma_5d - ma_10d: 0.947
# std_5d - std_10d: 0.881

# %%
y1 = df['forward_ret_1d']
X1 = df[['avg_sentiment','sentiment_std','comment_count',
            'sentiment_consensus','close','volume','amount','amplitude','pct_change',
               'price_change','turnover_rate']]
            
res1 = PanelOLS(y1, sm.add_constant(X1), entity_effects=True, time_effects=True).fit()
print(res1)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.0582
# Estimator:                   PanelOLS   R-squared (Between):             -487.48
# No. Observations:                1989   R-squared (Within):               0.0731
# Date:                Mon, Mar 24 2025   R-squared (Overall):             -24.260
# Time:                        10:58:28   Log-likelihood                    4820.3
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      10.388
# Entities:                         111   P-value                           0.0000
# Avg Obs:                       17.919   Distribution:                 F(11,1850)
# Min Obs:                       12.000
# Max Obs:                       18.000   F-statistic (robust):             10.388
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                 F(11,1850)
# Avg Obs:                       110.50
# Min Obs:                       108.00
# Max Obs:                       111.00
#
#                                   Parameter Estimates
# =======================================================================================
#                      Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------
# const                   0.0690     0.0116     5.9418     0.0000      0.0462      0.0918
# avg_sentiment           0.0140     0.0048     2.8975     0.0038      0.0045      0.0235
# sentiment_std           0.0024     0.0165     0.1454     0.8844     -0.0300      0.0348
# comment_count        -7.86e-06  6.381e-06    -1.2318     0.2182  -2.037e-05   4.654e-06
# sentiment_consensus    -0.0104     0.0078    -1.3235     0.1858     -0.0257      0.0050
# close                  -0.0008     0.0001    -8.0557     0.0000     -0.0010     -0.0006
# volume              -2.619e-09  2.282e-09    -1.1479     0.2511  -7.094e-09   1.856e-09
# amount              -1.832e-12   1.03e-12    -1.7785     0.0755  -3.851e-12   1.883e-13
# amplitude              -0.0013     0.0005    -2.6304     0.0086     -0.0023     -0.0003
# pct_change              0.0001     0.0003     0.4886     0.6252     -0.0004      0.0007
# price_change            0.0003     0.0002     1.4004     0.1616     -0.0001      0.0007
# turnover_rate           0.0008     0.0008     1.0702     0.2847     -0.0007      0.0023
# =======================================================================================
#
# F-test for Poolability: 5.8157
# P-value: 0.0000
# Distribution: F(127,1850)
#
# Included effects: Entity, Time

# %%
# 首先将date列转换为datetime格式
data['date'] = pd.to_datetime(data['date'])

# 设置索引
data1 = data.set_index(['stock_code','date'])

# 定义因变量列表
y_vars = ['close','volume','amount','amplitude','pct_change',
          'price_change','turnover_rate','forward_ret_1d',
          'forward_ret_3d','forward_ret_5d']

# 定义自变量
X_vars = ['avg_sentiment','sentiment_std','comment_count',
            'sentiment_consensus','ma_3d','std_3d']

# 存储结果的字典
regression_results = {}

# 批量回归
for y_var in y_vars:
    # 进行回归
    y = data1[y_var]
    X = data1[X_vars]
    model = PanelOLS(y, sm.add_constant(X), 
                     entity_effects=True, 
                     time_effects=True)
    results = model.fit()
    
    # 存储结果
    regression_results[y_var] = {
        'R-squared': results.rsquared,
        'R-squared Within': results.rsquared_within,
        'R-squared Between': results.rsquared_between,
        'R-squared Overall': results.rsquared_overall,
        'N_obs': results.nobs,
        'Parameters': results.params,
        't-stats': results.tstats,
        'P-values': results.pvalues,
        'F-statistic': results.f_statistic.stat
    }

# 打印结果摘要
for y_var, results in regression_results.items():
    print(f"\n=== 因变量: {y_var} ===")
    print(f"R-squared: {results['R-squared']:.4f}")
    print(f"R-squared Within: {results['R-squared Within']:.4f}")
    print(f"R-squared Between: {results['R-squared Between']:.4f}")
    print(f"R-squared Overall: {results['R-squared Overall']:.4f}")
    print(f"观测数: {results['N_obs']}")
    print(f"F-statistic: {results['F-statistic']:.4f}")
    print("\n系数估计:")
    for var, coef, tstat, pval in zip(
        results['Parameters'].index,
        results['Parameters'],
        results['t-stats'],
        results['P-values']
    ):
        print(f"{var:20} {coef:10.4f} (t={tstat:8.4f}) p={pval:.4f}")

# 将结果整理成DataFrame
summary_df = pd.DataFrame({
    'Y Variable': [],
    'R-squared': [],
    'R-squared Within': [],
    'R-squared Between': [],
    'R-squared Overall': [],
    'N_obs': [],
    'F-statistic': []
})

for y_var, results in regression_results.items():
    summary_df = pd.concat([summary_df, pd.DataFrame({
        'Y Variable': [y_var],
        'R-squared': [results['R-squared']],
        'R-squared Within': [results['R-squared Within']],
        'R-squared Between': [results['R-squared Between']],
        'R-squared Overall': [results['R-squared Overall']],
        'N_obs': [results['N_obs']],
        'F-statistic': [results['F-statistic']]
    })], ignore_index=True)

print("\n=== 回归结果汇总 ===")
print(summary_df)

# 导出到Excel
with pd.ExcelWriter('panel_regression_results.xlsx') as writer:
    summary_df.to_excel(writer, sheet_name='Summary', index=False)
    
    # 每个回归的详细结果
    for y_var, results in regression_results.items():
        pd.DataFrame({
            'Coefficient': results['Parameters'],
            't-statistic': results['t-stats'],
            'P-value': results['P-values']
        }).to_excel(writer, sheet_name=f'{y_var[:30]}')
# Out:
# === 因变量: close ===
# R-squared: 0.0251
# R-squared Within: 0.0091
# R-squared Between: -0.0002
# R-squared Overall: -0.0003
# 观测数: 1879
# F-statistic: 7.4828
#
# 系数估计:
# const                   60.9146 (t= 19.6998) p=0.0000
# avg_sentiment           -0.6804 (t= -0.7462) p=0.4557
# sentiment_std           -1.6225 (t= -0.3817) p=0.7027
# comment_count           -0.0043 (t= -3.9101) p=0.0001
# sentiment_consensus      1.8667 (t=  0.9193) p=0.3581
# ma_3d                    6.0344 (t=  4.3634) p=0.0000
# std_3d                   1.8771 (t=  1.2184) p=0.2232
#
# === 因变量: volume ===
# R-squared: 0.2537
# R-squared Within: 0.2486
# R-squared Between: 0.1610
# R-squared Overall: 0.1568
# 观测数: 1879
# F-statistic: 98.9422
#
# 系数估计:
# const                496921.0190 (t=  2.8377) p=0.0046
# avg_sentiment        133915.5635 (t=  2.5933) p=0.0096
# sentiment_std        -625448.5532 (t= -2.5982) p=0.0095
# comment_count         1375.1300 (t= 22.2734) p=0.0000
# sentiment_consensus  596138.7817 (t=  5.1841) p=0.0000
# ma_3d                104134.1859 (t=  1.3296) p=0.1838
# std_3d               245853.1601 (t=  2.8178) p=0.0049
#
# === 因变量: amount ===
# R-squared: 0.3088
# R-squared Within: 0.2977
# R-squared Between: 0.4524
# R-squared Overall: 0.4347
# 观测数: 1879
# F-statistic: 130.0109
#
# 系数估计:
# const                1233317469.9680 (t=  2.9474) p=0.0032
# avg_sentiment        489703632.2132 (t=  3.9686) p=0.0001
# sentiment_std        -1200554096.6482 (t= -2.0871) p=0.0370
# comment_count        3839803.0885 (t= 26.0279) p=0.0000
# sentiment_consensus  977053129.3509 (t=  3.5557) p=0.0004
# ma_3d                299489758.9347 (t=  1.6003) p=0.1097
# std_3d               290050924.5753 (t=  1.3912) p=0.1643
#
# === 因变量: amplitude ===
# R-squared: 0.2436
# R-squared Within: 0.2261
# R-squared Between: 0.0781
# R-squared Overall: 0.1511
# 观测数: 1879
# F-statistic: 93.7360
#
# 系数估计:
# const                    3.9829 (t=  4.6327) p=0.0000
# avg_sentiment            1.1264 (t=  4.4430) p=0.0000
# sentiment_std           -4.8109 (t= -4.0706) p=0.0000
# comment_count            0.0063 (t= 20.7539) p=0.0000
# sentiment_consensus      3.1210 (t=  5.5279) p=0.0000
# ma_3d                    0.6019 (t=  1.5654) p=0.1177
# std_3d                   0.3244 (t=  0.7572) p=0.4490
#
# === 因变量: pct_change ===
# R-squared: 0.1377
# R-squared Within: 0.1124
# R-squared Between: -1.1463
# R-squared Overall: 0.0564
# 观测数: 1879
# F-statistic: 46.4573
#
# 系数估计:
# const                    0.3733 (t=  0.2681) p=0.7887
# avg_sentiment            4.3213 (t= 10.5239) p=0.0000
# sentiment_std           -2.8759 (t= -1.5025) p=0.1332
# comment_count            0.0037 (t=  7.4423) p=0.0000
# sentiment_consensus      2.8092 (t=  3.0722) p=0.0022
# ma_3d                   -0.6920 (t= -1.1112) p=0.2666
# std_3d                  -1.0707 (t= -1.5432) p=0.1230
#
# === 因变量: price_change ===
# R-squared: 0.0396
# R-squared Within: 0.0385
# R-squared Between: -0.0821
# R-squared Overall: 0.0300
# 观测数: 1879
# F-statistic: 12.0106
#
# 系数估计:
# const                    1.9598 (t=  1.1309) p=0.2583
# avg_sentiment            2.4204 (t=  4.7363) p=0.0000
# sentiment_std           -4.2772 (t= -1.7954) p=0.0728
# comment_count            0.0033 (t=  5.3484) p=0.0000
# sentiment_consensus      2.2168 (t=  1.9479) p=0.0516
# ma_3d                   -0.6815 (t= -0.8793) p=0.3794
# std_3d                  -0.7290 (t= -0.8442) p=0.3987
#
# === 因变量: turnover_rate ===
# R-squared: 0.2921
# R-squared Within: 0.2830
# R-squared Between: 0.1819
# R-squared Overall: 0.1983
# 观测数: 1879
# F-statistic: 120.0785
#
# 系数估计:
# const                    2.8420 (t=  4.7664) p=0.0000
# avg_sentiment            0.4789 (t=  2.7235) p=0.0065
# sentiment_std           -3.7135 (t= -4.5306) p=0.0000
# comment_count            0.0049 (t= 23.5113) p=0.0000
# sentiment_consensus      2.4241 (t=  6.1909) p=0.0000
# ma_3d                    1.1654 (t=  4.3703) p=0.0000
# std_3d                  -0.1784 (t= -0.6006) p=0.5482
#
# === 因变量: forward_ret_1d ===
# R-squared: 0.0098
# R-squared Within: 0.0083
# R-squared Between: -0.3491
# R-squared Overall: -0.0089
# 观测数: 1879
# F-statistic: 2.8721
#
# 系数估计:
# const                   -0.0068 (t= -0.4444) p=0.6568
# avg_sentiment            0.0096 (t=  2.1318) p=0.0332
# sentiment_std            0.0209 (t=  0.9988) p=0.3180
# comment_count           -0.0000 (t= -3.0696) p=0.0022
# sentiment_consensus     -0.0069 (t= -0.6870) p=0.4922
# ma_3d                   -0.0068 (t= -0.9950) p=0.3199
# std_3d                  -0.0085 (t= -1.1267) p=0.2600
#
# === 因变量: forward_ret_3d ===
# R-squared: 0.0129
# R-squared Within: 0.0087
# R-squared Between: -0.2935
# R-squared Overall: -0.0297
# 观测数: 1879
# F-statistic: 3.7961
#
# 系数估计:
# const                    0.0219 (t=  0.8922) p=0.3724
# avg_sentiment            0.0099 (t=  1.3633) p=0.1730
# sentiment_std           -0.0102 (t= -0.3028) p=0.7621
# comment_count           -0.0000 (t= -3.6152) p=0.0003
# sentiment_consensus     -0.0030 (t= -0.1851) p=0.8532
# ma_3d                   -0.0272 (t= -2.4697) p=0.0136
# std_3d                  -0.0138 (t= -1.1284) p=0.2593
#
# === 因变量: forward_ret_5d ===
# R-squared: 0.0241
# R-squared Within: 0.0167
# R-squared Between: -0.2733
# R-squared Overall: -0.0427
# 观测数: 1879
# F-statistic: 7.1927
#
# 系数估计:
# const                    0.0234 (t=  0.7728) p=0.4397
# avg_sentiment            0.0172 (t=  1.9174) p=0.0553
# sentiment_std           -0.0074 (t= -0.1764) p=0.8600
# comment_count           -0.0000 (t= -2.3461) p=0.0191
# sentiment_consensus     -0.0107 (t= -0.5390) p=0.5900
# ma_3d                   -0.0733 (t= -5.4020) p=0.0000
# std_3d                  -0.0060 (t= -0.3948) p=0.6930
#
# === 回归结果汇总 ===
#        Y Variable  R-squared  R-squared Within  R-squared Between  \
# 0           close   0.025069          0.009104          -0.000245
# 1          volume   0.253736          0.248614           0.161009
# 2          amount   0.308807          0.297691           0.452379
# 3       amplitude   0.243637          0.226139           0.078081
# 4      pct_change   0.137669          0.112398          -1.146333
# 5    price_change   0.039638          0.038484          -0.082071
# 6   turnover_rate   0.292106          0.283039           0.181881
# 7  forward_ret_1d   0.009773          0.008349          -0.349054
# 8  forward_ret_3d   0.012877          0.008657          -0.293541
# 9  forward_ret_5d   0.024121          0.016742          -0.273264
#
#    R-squared Overall   N_obs  F-statistic
# 0          -0.000256  1879.0     7.482768
# 1           0.156756  1879.0    98.942248
# 2           0.434654  1879.0   130.010942
# 3           0.151108  1879.0    93.736028
# 4           0.056409  1879.0    46.457256
# 5           0.030002  1879.0    12.010633
# 6           0.198260  1879.0   120.078522
# 7          -0.008878  1879.0     2.872140
# 8          -0.029690  1879.0     3.796110
# 9          -0.042698  1879.0     7.192713
