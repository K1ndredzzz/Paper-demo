# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests
from linearmodels import PanelOLS, RandomEffects
from linearmodels.panel import compare
from scipy import stats
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv('stock_daily_sentiment.csv')
df['date'] = pd.to_datetime(df['date'])
df['stock_code'] = df['stock_code'].astype(str).str.zfill(6)

df = df.set_index(['stock_code', 'date'])

# 定义因变量和自变量
y = df['forward_ret_1d']  # 可以改为forward_ret_3d或forward_ret_5d
X = df[['avg_sentiment', 'sentiment_std', 
             'avg_intensity', 'comment_count', 'sentiment_consensus', 
             'close', 'volume', 'amount', 'amplitude',
             'pct_change', 'price_change', 'turnover_rate']]
X = sm.add_constant(X)



# 1. 普通最小二乘法 (OLS) 回归
ols_model = PanelOLS(y, X)
ols_results = ols_model.fit()
print("普通最小二乘法 (OLS) 回归结果:")
print(ols_results)

# 2. 考虑个体固定效应的面板回归
# 设置股票代码为实体 (entity)
fixed_entity = PanelOLS(y, X, entity_effects=True)
fe_entity_results = fixed_entity.fit(cov_type='clustered', cluster_entity=True)  # 使用聚类标准误
print("\n考虑个体固定效应的面板回归结果:")
print(fe_entity_results)

# 3. 考虑时间固定效应的面板回归
# 设置日期为时间 (time)
fixed_time = PanelOLS(y, X, time_effects=True)
fe_time_results = fixed_time.fit(cov_type='clustered', cluster_entity=True)
print("\n考虑时间固定效应的面板回归结果:")
print(fe_time_results)

# 4. 同时考虑个体和时间固定效应的面板回归
fixed_both = PanelOLS(y, X, entity_effects=True, time_effects=True)
fe_both_results = fixed_both.fit(cov_type='clustered', cluster_entity=True)
print("\n同时考虑个体和时间固定效应的面板回归结果:")
print(fe_both_results)

# 5. 随机效应回归
random_effects = RandomEffects(y, X)
re_results = random_effects.fit(cov_type='clustered', cluster_entity=True)
print("\n随机效应回归结果:")
print(re_results)

comparison = compare({'OLS': ols_results, 'FE (Entity)': fe_entity_results,
               'FE (Time)': fe_time_results, 'FE (Both)': fe_both_results,
               'RE': re_results}, stars = True)
print(comparison)

# 3. Hausman检验
def hausman_test(fe_model, re_model):
    # 提取系数和协方差矩阵
    b_fe = fe_model.params
    b_re = re_model.params
    
    # 去除常数项后的系数差
    b_diff = b_fe - b_re
    
    # 计算协方差矩阵差
    var_fe = fe_model.cov
    var_re = re_model.cov
    var_diff = var_fe - var_re
    
    # Hausman统计量
    H = np.dot(np.dot(b_diff.T, np.linalg.inv(var_diff)), b_diff)
    
    # 自由度(参数个数)
    df = len(b_fe)
    
    # p值
    p_value = 1 - stats.chi2.cdf(H, df)
    
    return H, p_value

H_stat, p_val = hausman_test(fe_entity_results, re_results)
print("\nHausman检验结果:")
print(f"统计量: {H_stat:.4f}")
print(f"P值: {p_val:.4f}")
print("结论:", "拒绝随机效应，使用固定效应" if p_val < 0.05 else "接受随机效应")

# 可以添加行业固定效应
# 如果需要控制行业效应，在数据中加入行业虚拟变量
# 添加行业虚拟变量，但删除一个类别避免完全共线性
# 按市值大小分组回归
for group in df.groupby('industry'):
    industry_data = group[1]
    y = industry_data['forward_ret_1d']
    X = industry_data[['avg_sentiment', 'sentiment_std', 
             'avg_intensity', 'comment_count',
             'close', 'volume', 'amount', 'amplitude',
             'pct_change', 'price_change', 'turnover_rate']]
    X = sm.add_constant(X)
    
    fixed_effects = PanelOLS(y, X, entity_effects=True, time_effects=True)
    fe_results = fixed_effects.fit(cov_type='clustered', cluster_entity=True)
    print(f"\n{group[0]}行业的回归结果:")
    print(fe_results)
    #export_results(fe_results, f'{group[0]}fixed_effects_results.xlsx')

'''
# 输出回归结果到Excel（可选）
def export_results(results, filename):
    # 获取置信区间DataFrame
    conf_int = results.conf_int()
    
    # 创建摘要DataFrame
    summary_df = pd.DataFrame({
        'coefficient': results.params,
        'std_error': results.std_errors,
        't_stat': results.tstats,
        'p_value': results.pvalues,
        'conf_int_lower': conf_int.iloc[:, 0],  # 使用iloc正确获取第一列
        'conf_int_upper': conf_int.iloc[:, 1]   # 使用iloc正确获取第二列
    })
    summary_df.to_excel(filename)
export_results(re_results, 'random_effects_results.xlsx')
'''
# Out:
# 普通最小二乘法 (OLS) 回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.0121
# Estimator:                   PanelOLS   R-squared (Between):              0.2611
# No. Observations:                1989   R-squared (Within):              -0.0008
# Date:                Tue, Mar 18 2025   R-squared (Overall):              0.0121
# Time:                        15:09:37   Log-likelihood                    4486.6
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      2.0233
# Entities:                         111   P-value                           0.0191
# Avg Obs:                       17.919   Distribution:                 F(12,1976)
# Min Obs:                       12.000
# Max Obs:                       18.000   F-statistic (robust):             2.0233
#                                         P-value                           0.0191
# Time periods:                      18   Distribution:                 F(12,1976)
# Avg Obs:                       110.50
# Min Obs:                       108.00
# Max Obs:                       111.00
#
#                                   Parameter Estimates
# =======================================================================================
#                      Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------
# const                   0.0019     0.0124     0.1522     0.8791     -0.0225      0.0263
# avg_sentiment           0.0120     0.0048     2.5050     0.0123      0.0026      0.0214
# sentiment_std          -0.0109     0.0287    -0.3798     0.7041     -0.0671      0.0453
# avg_intensity           0.0220     0.0265     0.8283     0.4076     -0.0300      0.0739
# comment_count        2.634e-06   4.87e-06     0.5407     0.5887  -6.918e-06   1.219e-05
# sentiment_consensus    -0.0065     0.0105    -0.6167     0.5375     -0.0270      0.0141
# close                2.998e-06  4.365e-06     0.6869     0.4922  -5.562e-06   1.156e-05
# volume              -8.845e-10  7.203e-10    -1.2279     0.2196  -2.297e-09   5.282e-10
# amount              -1.056e-12  4.812e-13    -2.1943     0.0283      -2e-12  -1.122e-13
# amplitude               0.0006     0.0004     1.4940     0.1353     -0.0002      0.0014
# pct_change             -0.0002     0.0003    -0.8120     0.4169     -0.0008      0.0003
# price_change         3.847e-05     0.0002     0.1720     0.8634     -0.0004      0.0005
# turnover_rate           0.0004     0.0003     1.2166     0.2239     -0.0003      0.0011
# =======================================================================================
#
#
#
# 考虑个体固定效应的面板回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.0836
# Estimator:                   PanelOLS   R-squared (Between):             -914.08
# No. Observations:                1989   R-squared (Within):               0.0836
# Date:                Tue, Mar 18 2025   R-squared (Overall):             -45.541
# Time:                        15:09:37   Log-likelihood                    4611.8
# Cov. Estimator:             Clustered
#                                         F-statistic:                      14.186
# Entities:                         111   P-value                           0.0000
# Avg Obs:                       17.919   Distribution:                 F(12,1866)
# Min Obs:                       12.000
# Max Obs:                       18.000   F-statistic (robust):             6.5587
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                 F(12,1866)
# Avg Obs:                       110.50
# Min Obs:                       108.00
# Max Obs:                       111.00
#
#                                   Parameter Estimates
# =======================================================================================
#                      Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------
# const                   0.0928     0.0225     4.1220     0.0000      0.0486      0.1369
# avg_sentiment           0.0158     0.0068     2.3343     0.0197      0.0025      0.0292
# sentiment_std          -0.0195     0.0177    -1.1037     0.2698     -0.0543      0.0152
# avg_intensity           0.0166     0.0179     0.9275     0.3538     -0.0185      0.0516
# comment_count       -1.295e-05  7.834e-06    -1.6535     0.0984  -2.832e-05   2.411e-06
# sentiment_consensus    -0.0116     0.0095    -1.2207     0.2224     -0.0301      0.0070
# close                  -0.0011     0.0003    -3.9376     0.0001     -0.0017     -0.0006
# volume              -4.023e-09  2.144e-09    -1.8764     0.0607  -8.228e-09   1.818e-10
# amount               -1.88e-12  1.447e-12    -1.2990     0.1941  -4.718e-12   9.583e-13
# amplitude            7.159e-05     0.0007     0.1034     0.9177     -0.0013      0.0014
# pct_change             -0.0004     0.0003    -1.3714     0.1704     -0.0009      0.0002
# price_change            0.0004     0.0002     2.0242     0.0431   1.137e-05      0.0007
# turnover_rate          -0.0004     0.0022    -0.1705     0.8646     -0.0046      0.0039
# =======================================================================================
#
# F-test for Poolability: 2.2763
# P-value: 0.0000
# Distribution: F(110,1866)
#
# Included effects: Entity
#
# 考虑时间固定效应的面板回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.0145
# Estimator:                   PanelOLS   R-squared (Between):              0.2723
# No. Observations:                1989   R-squared (Within):              -0.0044
# Date:                Tue, Mar 18 2025   R-squared (Overall):              0.0092
# Time:                        15:09:37   Log-likelihood                    4712.5
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2.4070
# Entities:                         111   P-value                           0.0043
# Avg Obs:                       17.919   Distribution:                 F(12,1959)
# Min Obs:                       12.000
# Max Obs:                       18.000   F-statistic (robust):             1.5950
#                                         P-value                           0.0862
# Time periods:                      18   Distribution:                 F(12,1959)
# Avg Obs:                       110.50
# Min Obs:                       108.00
# Max Obs:                       111.00
#
#                                   Parameter Estimates
# =======================================================================================
#                      Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------
# const                  -0.0009     0.0084    -0.1102     0.9123     -0.0174      0.0155
# avg_sentiment           0.0117     0.0058     2.0155     0.0440      0.0003      0.0231
# sentiment_std           0.0026     0.0156     0.1654     0.8687     -0.0280      0.0332
# avg_intensity           0.0111     0.0157     0.7066     0.4799     -0.0197      0.0420
# comment_count        4.464e-06  3.625e-06     1.2315     0.2183  -2.645e-06   1.157e-05
# sentiment_consensus    -0.0049     0.0081    -0.6066     0.5442     -0.0207      0.0109
# close                3.501e-06  2.182e-06     1.6047     0.1087  -7.777e-07   7.779e-06
# volume              -7.254e-10  4.444e-10    -1.6321     0.1028  -1.597e-09   1.462e-10
# amount              -1.063e-12  3.916e-13    -2.7137     0.0067  -1.831e-12  -2.947e-13
# amplitude           -6.743e-05     0.0005    -0.1351     0.8926     -0.0010      0.0009
# pct_change              0.0001     0.0003     0.3713     0.7104     -0.0005      0.0007
# price_change          2.82e-05     0.0002     0.1800     0.8572     -0.0003      0.0003
# turnover_rate           0.0009     0.0005     1.6242     0.1045     -0.0002      0.0019
# =======================================================================================
#
# F-test for Poolability: 29.391
# P-value: 0.0000
# Distribution: F(17,1959)
#
# Included effects: Time
#
# 同时考虑个体和时间固定效应的面板回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.0582
# Estimator:                   PanelOLS   R-squared (Between):             -487.36
# No. Observations:                1989   R-squared (Within):               0.0732
# Date:                Tue, Mar 18 2025   R-squared (Overall):             -24.254
# Time:                        15:09:37   Log-likelihood                    4820.4
# Cov. Estimator:             Clustered
#                                         F-statistic:                      9.5285
# Entities:                         111   P-value                           0.0000
# Avg Obs:                       17.919   Distribution:                 F(12,1849)
# Min Obs:                       12.000
# Max Obs:                       18.000   F-statistic (robust):             4.3760
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                 F(12,1849)
# Avg Obs:                       110.50
# Min Obs:                       108.00
# Max Obs:                       111.00
#
#                                   Parameter Estimates
# =======================================================================================
#                      Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------
# const                   0.0665     0.0193     3.4377     0.0006      0.0286      0.1044
# avg_sentiment           0.0144     0.0061     2.3747     0.0177      0.0025      0.0263
# sentiment_std          -0.0048     0.0176    -0.2735     0.7845     -0.0392      0.0296
# avg_intensity           0.0087     0.0159     0.5478     0.5839     -0.0225      0.0399
# comment_count       -7.907e-06  7.855e-06    -1.0067     0.3142  -2.331e-05   7.497e-06
# sentiment_consensus    -0.0082     0.0098    -0.8449     0.3983     -0.0274      0.0109
# close                  -0.0008     0.0003    -3.2181     0.0013     -0.0013     -0.0003
# volume              -2.644e-09   2.24e-09    -1.1802     0.2381  -7.038e-09    1.75e-09
# amount              -1.826e-12   1.39e-12    -1.3136     0.1891  -4.551e-12       9e-13
# amplitude              -0.0013     0.0007    -1.9664     0.0494     -0.0026  -3.428e-06
# pct_change              0.0001     0.0003     0.4672     0.6404     -0.0005      0.0008
# price_change            0.0003     0.0002     1.5214     0.1283  -8.263e-05      0.0007
# turnover_rate           0.0008     0.0022     0.3681     0.7128     -0.0035      0.0051
# =======================================================================================
#
# F-test for Poolability: 5.8069
# P-value: 0.0000
# Distribution: F(127,1849)
#
# Included effects: Entity, Time
# 随机效应回归结果:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.0121
# Estimator:              RandomEffects   R-squared (Between):              0.2611
# No. Observations:                1989   R-squared (Within):              -0.0008
# Date:                Tue, Mar 18 2025   R-squared (Overall):              0.0121
# Time:                        15:09:37   Log-likelihood                    4486.6
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2.0233
# Entities:                         111   P-value                           0.0191
# Avg Obs:                       17.919   Distribution:                 F(12,1976)
# Min Obs:                       12.000
# Max Obs:                       18.000   F-statistic (robust):             2.4503
#                                         P-value                           0.0036
# Time periods:                      18   Distribution:                 F(12,1976)
# Avg Obs:                       110.50
# Min Obs:                       108.00
# Max Obs:                       111.00
#
#                                   Parameter Estimates
# =======================================================================================
#                      Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------
# const                   0.0019     0.0099     0.1913     0.8483     -0.0175      0.0213
# avg_sentiment           0.0120     0.0062     1.9227     0.0547     -0.0002      0.0243
# sentiment_std          -0.0109     0.0168    -0.6462     0.5183     -0.0439      0.0221
# avg_intensity           0.0220     0.0176     1.2495     0.2116     -0.0125      0.0564
# comment_count        2.634e-06  3.795e-06     0.6939     0.4878   -4.81e-06   1.008e-05
# sentiment_consensus    -0.0065     0.0083    -0.7771     0.4372     -0.0228      0.0099
# close                2.998e-06  1.953e-06     1.5354     0.1248  -8.314e-07   6.828e-06
# volume              -8.845e-10  4.469e-10    -1.9790     0.0479  -1.761e-09  -7.991e-12
# amount              -1.056e-12   4.04e-13    -2.6141     0.0090  -1.848e-12  -2.638e-13
# amplitude               0.0006     0.0005     1.2016     0.2296     -0.0004      0.0016
# pct_change             -0.0002     0.0003    -0.7874     0.4311     -0.0008      0.0003
# price_change         3.847e-05     0.0001     0.2700     0.7872     -0.0002      0.0003
# turnover_rate           0.0004     0.0005     0.8028     0.4222     -0.0006      0.0015
# =======================================================================================
#                                                    Model Comparison
# ======================================================================================================================
#                                        OLS        FE (Entity)          FE (Time)          FE (Both)                 RE
# ----------------------------------------------------------------------------------------------------------------------
# Dep. Variable               forward_ret_1d     forward_ret_1d     forward_ret_1d     forward_ret_1d     forward_ret_1d
# Estimator                         PanelOLS           PanelOLS           PanelOLS           PanelOLS      RandomEffects
# No. Observations                      1989               1989               1989               1989               1989
# Cov. Est.                       Unadjusted          Clustered          Clustered          Clustered          Clustered
# R-squared                           0.0121             0.0836             0.0145             0.0582             0.0121
# R-Squared (Within)                 -0.0008             0.0836            -0.0044             0.0732            -0.0008
# R-Squared (Between)                 0.2611            -914.08             0.2723            -487.36             0.2611
# R-Squared (Overall)                 0.0121            -45.541             0.0092            -24.254             0.0121
# F-statistic                         2.0233             14.186             2.4070             9.5285             2.0233
# P-value (F-stat)                    0.0191             0.0000             0.0043             0.0000             0.0191
# =====================     ================   ================   ================   ================   ================
# const                               0.0019          0.0928***            -0.0009          0.0665***             0.0019
#                                   (0.1522)           (4.1220)          (-0.1102)           (3.4377)           (0.1913)
# avg_sentiment                     0.0120**           0.0158**           0.0117**           0.0144**            0.0120*
#                                   (2.5050)           (2.3343)           (2.0155)           (2.3747)           (1.9227)
# sentiment_std                      -0.0109            -0.0195             0.0026            -0.0048            -0.0109
#                                  (-0.3798)          (-1.1037)           (0.1654)          (-0.2735)          (-0.6462)
# avg_intensity                       0.0220             0.0166             0.0111             0.0087             0.0220
#                                   (0.8283)           (0.9275)           (0.7066)           (0.5478)           (1.2495)
# comment_count                    2.634e-06        -1.295e-05*          4.464e-06         -7.907e-06          2.634e-06
#                                   (0.5407)          (-1.6535)           (1.2315)          (-1.0067)           (0.6939)
# sentiment_consensus                -0.0065            -0.0116            -0.0049            -0.0082            -0.0065
#                                  (-0.6167)          (-1.2207)          (-0.6066)          (-0.8449)          (-0.7771)
# close                            2.998e-06         -0.0011***          3.501e-06         -0.0008***          2.998e-06
#                                   (0.6869)          (-3.9376)           (1.6047)          (-3.2181)           (1.5354)
# volume                          -8.845e-10        -4.023e-09*         -7.254e-10         -2.644e-09       -8.845e-10**
#                                  (-1.2279)          (-1.8764)          (-1.6321)          (-1.1802)          (-1.9790)
# amount                        -1.056e-12**          -1.88e-12      -1.063e-12***         -1.826e-12      -1.056e-12***
#                                  (-2.1943)          (-1.2990)          (-2.7137)          (-1.3136)          (-2.6141)
# amplitude                           0.0006          7.159e-05         -6.743e-05          -0.0013**             0.0006
#                                   (1.4940)           (0.1034)          (-0.1351)          (-1.9664)           (1.2016)
# pct_change                         -0.0002            -0.0004             0.0001             0.0001            -0.0002
#                                  (-0.8120)          (-1.3714)           (0.3713)           (0.4672)          (-0.7874)
# price_change                     3.847e-05           0.0004**           2.82e-05             0.0003          3.847e-05
#                                   (0.1720)           (2.0242)           (0.1800)           (1.5214)           (0.2700)
# turnover_rate                       0.0004            -0.0004             0.0009             0.0008             0.0004
#                                   (1.2166)          (-0.1705)           (1.6242)           (0.3681)           (0.8028)
# ======================= ================== ================== ================== ================== ==================
# Effects                                                Entity               Time             Entity
#                                                                                                Time
# ----------------------------------------------------------------------------------------------------------------------
#
# T-stats reported in parentheses
#
# Hausman检验结果:
# 统计量: 60.0649
# P值: 0.0000
# 结论: 拒绝随机效应，使用固定效应
#
# 医药生物行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.1788
# Estimator:                   PanelOLS   R-squared (Between):             -1113.5
# No. Observations:                 286   R-squared (Within):               0.2253
# Date:                Tue, Mar 18 2025   R-squared (Overall):             -62.014
# Time:                        15:09:37   Log-likelihood                    772.48
# Cov. Estimator:             Clustered
#                                         F-statistic:                      4.7911
# Entities:                          16   P-value                           0.0000
# Avg Obs:                       17.875   Distribution:                  F(11,242)
# Min Obs:                       16.000
# Max Obs:                       18.000   F-statistic (robust):             62.204
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(11,242)
# Avg Obs:                       15.889
# Min Obs:                       15.000
# Max Obs:                       16.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.2109     0.0658     3.2048     0.0015      0.0813      0.3405
# avg_sentiment     0.0158     0.0118     1.3382     0.1821     -0.0074      0.0390
# sentiment_std    -0.0113     0.0207    -0.5471     0.5848     -0.0520      0.0294
# avg_intensity    -0.0248     0.0265    -0.9356     0.3504     -0.0770      0.0274
# comment_count  6.401e-06  2.921e-05     0.2192     0.8267  -5.113e-05   6.393e-05
# close            -0.0031     0.0011    -2.7268     0.0069     -0.0053     -0.0009
# volume        -3.462e-08  6.607e-09    -5.2389     0.0000  -4.763e-08   -2.16e-08
# amount         1.015e-11  4.798e-12     2.1162     0.0353   7.023e-13    1.96e-11
# amplitude         0.0016     0.0011     1.5230     0.1291     -0.0005      0.0037
# pct_change        0.0003     0.0005     0.5132     0.6083     -0.0008      0.0013
# price_change     -0.0016     0.0004    -4.4412     0.0000     -0.0023     -0.0009
# turnover_rate    -0.0073     0.0014    -5.3454     0.0000     -0.0101     -0.0046
# =================================================================================
#
# F-test for Poolability: 9.7450
# P-value: 0.0000
# Distribution: F(32,242)
#
# Included effects: Entity, Time
#
# 房地产行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.1379
# Estimator:                   PanelOLS   R-squared (Between):             -1988.1
# No. Observations:                 198   R-squared (Within):               0.1438
# Date:                Tue, Mar 18 2025   R-squared (Overall):             -32.675
# Time:                        15:09:37   Log-likelihood                    543.34
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2.3117
# Entities:                          78   P-value                           0.0117
# Avg Obs:                       2.5385   Distribution:                  F(11,159)
# Min Obs:                       0.0000
# Max Obs:                       18.000   F-statistic (robust):         -2.372e+12
#                                         P-value                           1.0000
# Time periods:                      18   Distribution:                  F(11,159)
# Avg Obs:                       11.000
# Min Obs:                       11.000
# Max Obs:                       11.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.1675     0.1133     1.4788     0.1412     -0.0562      0.3912
# avg_sentiment     0.0015     0.0080     0.1855     0.8531     -0.0144      0.0173
# sentiment_std     0.0269     0.0221     1.2177     0.2252     -0.0168      0.0707
# avg_intensity    -0.0210     0.0272    -0.7737     0.4403     -0.0748      0.0327
# comment_count -1.483e-06    2.2e-05    -0.0674     0.9463  -4.493e-05   4.197e-05
# close            -0.0235     0.0156    -1.5069     0.1338     -0.0543      0.0073
# volume         1.136e-08  1.005e-08     1.1305     0.2600  -8.489e-09   3.122e-08
# amount         -1.31e-11  1.073e-11    -1.2208     0.2240   -3.43e-11   8.093e-12
# amplitude        -0.0005     0.0019    -0.2415     0.8095     -0.0042      0.0033
# pct_change       -0.0022     0.0007    -3.2740     0.0013     -0.0035     -0.0009
# price_change      0.0098     0.0076     1.2883     0.1995     -0.0052      0.0249
# turnover_rate    -0.0032     0.0021    -1.5344     0.1269     -0.0073      0.0009
# =================================================================================
#
# F-test for Poolability: 6.4478
# P-value: 0.0000
# Distribution: F(27,159)
#
# Included effects: Entity, Time
#
# 有色金属行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.1843
# Estimator:                   PanelOLS   R-squared (Between):             -398.00
# No. Observations:                 270   R-squared (Within):               0.1927
# Date:                Tue, Mar 18 2025   R-squared (Overall):             -19.918
# Time:                        15:09:37   Log-likelihood                    811.72
# Cov. Estimator:             Clustered
#                                         F-statistic:                      4.6627
# Entities:                         110   P-value                           0.0000
# Avg Obs:                       2.4545   Distribution:                  F(11,227)
# Min Obs:                       0.0000
# Max Obs:                       18.000   F-statistic (robust):             66.240
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(11,227)
# Avg Obs:                       15.000
# Min Obs:                       15.000
# Max Obs:                       15.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.1791     0.1042     1.7185     0.0871     -0.0263      0.3845
# avg_sentiment     0.0150     0.0148     1.0169     0.3103     -0.0141      0.0441
# sentiment_std    -0.0999     0.0658    -1.5166     0.1308     -0.2296      0.0299
# avg_intensity     0.0438     0.0412     1.0642     0.2884     -0.0373      0.1250
# comment_count  4.651e-07  2.406e-05     0.0193     0.9846  -4.695e-05   4.788e-05
# close            -0.0083     0.0061    -1.3550     0.1768     -0.0204      0.0038
# volume        -7.313e-09  5.053e-09    -1.4473     0.1492  -1.727e-08   2.644e-09
# amount         1.017e-11  4.542e-12     2.2392     0.0261   1.221e-12   1.912e-11
# amplitude        -0.0003     0.0014    -0.2048     0.8379     -0.0031      0.0025
# pct_change        0.0013     0.0012     1.0644     0.2883     -0.0011      0.0037
# price_change     -0.0192     0.0040    -4.7703     0.0000     -0.0272     -0.0113
# turnover_rate     0.0014     0.0042     0.3412     0.7333     -0.0068      0.0097
# =================================================================================
#
# F-test for Poolability: 7.3402
# P-value: 0.0000
# Distribution: F(31,227)
#
# Included effects: Entity, Time
# 电子行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.1017
# Estimator:                   PanelOLS   R-squared (Between):             -145.90
# No. Observations:                 252   R-squared (Within):               0.0623
# Date:                Tue, Mar 18 2025   R-squared (Overall):             -3.6531
# Time:                        15:09:37   Log-likelihood                    616.68
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2.1614
# Entities:                         109   P-value                           0.0177
# Avg Obs:                       2.3119   Distribution:                  F(11,210)
# Min Obs:                       0.0000
# Max Obs:                       18.000   F-statistic (robust):             27.778
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(11,210)
# Avg Obs:                       14.000
# Min Obs:                       14.000
# Max Obs:                       14.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.0547     0.0335     1.6327     0.1040     -0.0114      0.1208
# avg_sentiment     0.0307     0.0154     1.9946     0.0474      0.0004      0.0611
# sentiment_std    -0.2512     0.0728    -3.4484     0.0007     -0.3948     -0.1076
# avg_intensity     0.2572     0.0768     3.3491     0.0010      0.1058      0.4085
# comment_count  1.861e-05  2.019e-05     0.9218     0.3577  -2.119e-05   5.842e-05
# close            -0.0005     0.0003    -1.8166     0.0707     -0.0011   4.295e-05
# volume         7.096e-09  3.458e-09     2.0520     0.0414   2.789e-10   1.391e-08
# amount        -5.335e-12   2.51e-12    -2.1256     0.0347  -1.028e-11  -3.872e-13
# amplitude        -0.0009     0.0008    -1.1433     0.2542     -0.0023      0.0006
# pct_change        0.0010     0.0007     1.4645     0.1445     -0.0003      0.0023
# price_change     -0.0005     0.0004    -1.2089     0.2280     -0.0013      0.0003
# turnover_rate     0.0029     0.0022     1.3051     0.1933     -0.0015      0.0073
# =================================================================================
#
# F-test for Poolability: 8.3191
# P-value: 0.0000
# Distribution: F(30,210)
#
# Included effects: Entity, Time
#
# 电气设备行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.3291
# Estimator:                   PanelOLS   R-squared (Between):             -387.97
# No. Observations:                 198   R-squared (Within):               0.2155
# Date:                Tue, Mar 18 2025   R-squared (Overall):             -12.448
# Time:                        15:09:37   Log-likelihood                    530.77
# Cov. Estimator:             Clustered
#                                         F-statistic:                      7.0918
# Entities:                          93   P-value                           0.0000
# Avg Obs:                       2.1290   Distribution:                  F(11,159)
# Min Obs:                       0.0000
# Max Obs:                       18.000   F-statistic (robust):          1.603e+16
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(11,159)
# Avg Obs:                       11.000
# Min Obs:                       11.000
# Max Obs:                       11.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.0714     0.0666     1.0714     0.2856     -0.0602      0.2030
# avg_sentiment     0.0125     0.0284     0.4407     0.6600     -0.0435      0.0686
# sentiment_std    -0.0003     0.0848    -0.0034     0.9973     -0.1677      0.1671
# avg_intensity    -0.0132     0.0786    -0.1686     0.8664     -0.1685      0.1420
# comment_count -4.613e-06  8.539e-06    -0.5402     0.5898  -2.148e-05   1.225e-05
# close            -0.0007  9.763e-05    -7.4167     0.0000     -0.0009     -0.0005
# volume        -9.951e-09  8.026e-09    -1.2398     0.2169   -2.58e-08   5.901e-09
# amount        -3.362e-12  1.394e-12    -2.4122     0.0170  -6.114e-12  -6.093e-13
# amplitude        -0.0030     0.0014    -2.0777     0.0393     -0.0058     -0.0001
# pct_change       -0.0008     0.0014    -0.5893     0.5565     -0.0036      0.0020
# price_change      0.0004     0.0006     0.7275     0.4680     -0.0007      0.0016
# turnover_rate     0.0122     0.0008     15.694     0.0000      0.0107      0.0137
# =================================================================================
#
# F-test for Poolability: 7.7880
# P-value: 0.0000
# Distribution: F(27,159)
#
# Included effects: Entity, Time
#
# 计算机行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.1575
# Estimator:                   PanelOLS   R-squared (Between):             -127.17
# No. Observations:                 246   R-squared (Within):               0.1444
# Date:                Tue, Mar 18 2025   R-squared (Overall):             -7.7775
# Time:                        15:09:37   Log-likelihood                    548.04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      3.4674
# Entities:                         111   P-value                           0.0002
# Avg Obs:                       2.2162   Distribution:                  F(11,204)
# Min Obs:                       0.0000
# Max Obs:                       18.000   F-statistic (robust):             44.170
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(11,204)
# Avg Obs:                       13.667
# Min Obs:                       13.000
# Max Obs:                       14.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.1192     0.0485     2.4567     0.0149      0.0235      0.2149
# avg_sentiment     0.0489     0.0274     1.7860     0.0756     -0.0051      0.1028
# sentiment_std    -0.0616     0.0794    -0.7757     0.4388     -0.2180      0.0949
# avg_intensity     0.0731     0.0670     1.0915     0.2763     -0.0590      0.2052
# comment_count -2.555e-05  2.855e-05    -0.8948     0.3719  -8.185e-05   3.075e-05
# close            -0.0014     0.0002    -7.2493     0.0000     -0.0018     -0.0011
# volume        -7.335e-09  5.828e-09    -1.2586     0.2096  -1.882e-08   4.156e-09
# amount         1.024e-12  2.382e-12     0.4298     0.6678  -3.673e-12    5.72e-12
# amplitude        -0.0010     0.0017    -0.5529     0.5809     -0.0044      0.0025
# pct_change       -0.0006     0.0008    -0.7372     0.4618     -0.0022      0.0010
# price_change      0.0001     0.0002     0.7905     0.4301     -0.0002      0.0005
# turnover_rate    -0.0005     0.0014    -0.3789     0.7051     -0.0033      0.0023
# =================================================================================
#
# F-test for Poolability: 9.1730
# P-value: 0.0000
# Distribution: F(30,204)
#
# Included effects: Entity, Time
#
# 银行行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.1370
# Estimator:                   PanelOLS   R-squared (Between):             -1442.5
# No. Observations:                 269   R-squared (Within):               0.0521
# Date:                Tue, Mar 18 2025   R-squared (Overall):             -45.572
# Time:                        15:09:37   Log-likelihood                    1048.9
# Cov. Estimator:             Clustered
#                                         F-statistic:                      3.2625
# Entities:                          15   P-value                           0.0004
# Avg Obs:                       17.933   Distribution:                  F(11,226)
# Min Obs:                       17.000
# Max Obs:                       18.000   F-statistic (robust):             7.6087
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(11,226)
# Avg Obs:                       14.944
# Min Obs:                       14.000
# Max Obs:                       15.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.0607     0.0206     2.9421     0.0036      0.0200      0.1014
# avg_sentiment    -0.0044     0.0034    -1.3087     0.1920     -0.0110      0.0022
# sentiment_std     0.0102     0.0159     0.6408     0.5223     -0.0211      0.0415
# avg_intensity    -0.0115     0.0143    -0.8056     0.4213     -0.0396      0.0166
# comment_count  3.179e-06  3.737e-06     0.8507     0.3958  -4.185e-06   1.054e-05
# close            -0.0059     0.0021    -2.7923     0.0057     -0.0100     -0.0017
# volume         8.786e-10  1.889e-09     0.4651     0.6423  -2.844e-09   4.601e-09
# amount        -2.242e-12   3.19e-12    -0.7028     0.4829  -8.527e-12   4.044e-12
# amplitude        -0.0032     0.0014    -2.3435     0.0200     -0.0059     -0.0005
# pct_change       -0.0006     0.0012    -0.5535     0.5804     -0.0029      0.0016
# price_change      0.0029     0.0026     1.1245     0.2620     -0.0022      0.0081
# turnover_rate     0.0052     0.0027     1.9614     0.0511  -2.432e-05      0.0105
# =================================================================================
#
# F-test for Poolability: 14.227
# P-value: 0.0000
# Distribution: F(31,226)
#
# Included effects: Entity, Time
#
# 食品饮料行业的回归结果:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         forward_ret_1d   R-squared:                        0.0626
# Estimator:                   PanelOLS   R-squared (Between):             -45.512
# No. Observations:                 270   R-squared (Within):               0.0888
# Date:                Tue, Mar 18 2025   R-squared (Overall):             -1.2922
# Time:                        15:09:37   Log-likelihood                    825.64
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1.3787
# Entities:                         104   P-value                           0.1840
# Avg Obs:                       2.5962   Distribution:                  F(11,227)
# Min Obs:                       0.0000
# Max Obs:                       18.000   F-statistic (robust):             4.4083
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(11,227)
# Avg Obs:                       15.000
# Min Obs:                       15.000
# Max Obs:                       15.000
#
#                                Parameter Estimates
# =================================================================================
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             0.0157     0.0224     0.7023     0.4832     -0.0284      0.0599
# avg_sentiment     0.0163     0.0147     1.1124     0.2671     -0.0126      0.0452
# sentiment_std    -0.0154     0.0278    -0.5537     0.5804     -0.0703      0.0395
# avg_intensity     0.0187     0.0269     0.6975     0.4862     -0.0342      0.0717
# comment_count  1.591e-05  1.909e-05     0.8331     0.4057  -2.172e-05   5.353e-05
# close         -5.394e-05   6.34e-05    -0.8508     0.3958     -0.0002   7.098e-05
# volume        -1.519e-08  1.777e-08    -0.8545     0.3938  -5.021e-08   1.983e-08
# amount         -6.89e-13  1.068e-12    -0.6448     0.5197  -2.794e-12   1.416e-12
# amplitude         0.0003     0.0016     0.1607     0.8725     -0.0029      0.0034
# pct_change       -0.0009     0.0011    -0.7797     0.4364     -0.0031      0.0013
# price_change   3.026e-07   6.94e-05     0.0044     0.9965     -0.0001      0.0001
# turnover_rate    -0.0052     0.0018    -2.9341     0.0037     -0.0088     -0.0017
# =================================================================================
#
# F-test for Poolability: 4.8435
# P-value: 0.0000
# Distribution: F(31,227)
#
# Included effects: Entity, Time
# "\n# 输出回归结果到Excel（可选）\ndef export_results(results, filename):\n    # 获取置信区间DataFrame\n    conf_int = results.conf_int()\n    \n    # 创建摘要DataFrame\n    summary_df = pd.DataFrame({\n        'coefficient': results.params,\n        'std_error': results.std_errors,\n        't_stat': results.tstats,\n        'p_value': results.pvalues,\n        'conf_int_lower': conf_int.iloc[:, 0],  # 使用iloc正确获取第一列\n        'conf_int_upper': conf_int.iloc[:, 1]   # 使用iloc正确获取第二列\n    })\n    summary_df.to_excel(filename)\nexport_results(re_results, 'random_effects_results.xlsx')\n"
